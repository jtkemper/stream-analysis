# %% [markdown]
# # Analysis of temporal analysis
# This code was written by Sai and Danyka Byrnes

# %%
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from config import *

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# #### Answer the following questions based on the timeseries data:
# 1) Percentage of Data missing between the start and end date.
#
# 2) The length between start and end datetime (hour)
#
# 3) longest continous recored between the start and end date.

# %%
# List of possible parameters
parameters = [
    "WTemp_C", "SpC_uScm", "DO_mgL", "pH",
    "Turb_FNU", "Turb_NTU", "NO3_mgNL",
    "fDOM_QSU", "fDOM_RFU", "DOC_mgL",
    "PO4_mgL", "Chla_ugL", "Chla_RFU",
    "PC_ugL", "PC_RFU"
]

# Store all results
results = []

# Loop through each CSV
for file in os.listdir(water_quality_filepath):
    if not file.endswith(".csv"):
        continue

    file_path = os.path.join(water_quality_filepath, file)
    
    # Extract STREAM_ID from filename (remove .csv)
    stream_id = os.path.splitext(file)[0]

    df = pd.read_csv(file_path)

    if "DateTime" not in df.columns:
        continue

    # Convert DateTime
    df["DateTime"] = pd.to_datetime(df["DateTime"], errors="coerce")
    df = df.dropna(subset=["DateTime"])
    df = df.sort_values("DateTime")

    # Create full hourly range
    start = df["DateTime"].min()
    end = df["DateTime"].max()
    full_range = pd.date_range(start=start, end=end, freq="h")

    # Reindex to full hourly timeline
    df = df.set_index("DateTime").reindex(full_range)

    # Total expected length in hours
    total_hours = len(full_range)

    station_result = {"STREAM_ID": stream_id}

    for param in parameters:
        if param in df.columns:

            series = df[param]

            # 1 Percentage Missing
            missing_count = series.isna().sum()
            percent_missing = (missing_count / total_hours) * 100

            # 2 Length between start and end
            length_hours = total_hours

            # 3 Longest continuous record (non-missing streak)
            not_na = series.notna().astype(int)
            groups = (not_na.diff() != 0).cumsum()
            streak_lengths = not_na.groupby(groups).sum()
            longest_streak = streak_lengths.max() if len(streak_lengths) > 0 else 0

            station_result[f"{param}_pct_missing"] = round(percent_missing, 2)
            station_result[f"{param}_length_hr"] = length_hours
            station_result[f"{param}_longest_hr"] = int(longest_streak)

        else:
            # If parameter not present
            station_result[f"{param}_pct_missing"] = np.nan
            station_result[f"{param}_length_hr"] = np.nan
            station_result[f"{param}_longest_hr"] = np.nan

    results.append(station_result)

# Convert to dataframe
temporal_summary = pd.DataFrame(results)

print("Processing complete.")
# Out:
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (4,6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (4,6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (4,6,8,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (12,14,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (6,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (2,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (2,4,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (2,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (12,14,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (4,6,8,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (14,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1752745080.py:23: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Processing complete.

# %%
# Merging the temporal data derived by Sai
# Identify ID/metadata columns (keep these as-is)
id_cols = ['STREAM_ID']

# Other parameters
temporal_params = ['WTemp_C', 'SpC_uScm', 'DO_mgL', 'pH', 'Turb_FNU', 'Turb_NTU',
          'NO3_mgNL', 'fDOM_QSU', 'fDOM_RFU', 'DOC_mgL', 'PO4_mgL', 
          'Chla_ugL', 'Chla_RFU', 'PC_ugL', 'PC_RFU']

# Reshape
rows = []
for temp_param in temporal_params:
    temp = temporal_summary[id_cols].copy()
    temp['parameter'] = temp_param
    temp['pct_missing'] = temporal_summary[f'{temp_param}_pct_missing']
    temp['length_hr'] = temporal_summary[f'{temp_param}_length_hr']
    temp['longest_hr'] = temporal_summary[f'{temp_param}_longest_hr']
    rows.append(temp)

temporal_summary_long = (
    pd.concat(rows, ignore_index=True)
    .query('parameter in @temporal_params')
    .dropna(how='all', subset=['pct_missing', 'length_hr', 'longest_hr'])
)
temporal_summary_long.head()
temporal_summary_long.to_csv(OUTPUT_filepath+'temporal_statistics.csv', index=False)

# %%
# Processing metadata, isolating specific parameters
md_wide = pd.read_csv(metadata_filepath+"metadata.csv", dtype = {'sourceID': str})
print(f"Full dataset size: {md_wide.shape[0]}")
params = ['SpC_uScm','DO_mgL','Turb_FNU']

for param in params:
    md_wide[param] = md_wide['WQ_parameters'].str.contains(param)

# Removing the stations without data
md_wide = md_wide[(md_wide['SpC_uScm']) | (md_wide['DO_mgL']) | (md_wide['Turb_FNU'])]
print(f"Filtered dataset size: {md_wide.shape[0]}")
# Out:
# Full dataset size: 870
# Filtered dataset size: 556

# %%
md_wide.head()
# Out:
#             STREAM_ID  sourceID source  \
# 0   STREAM-gauge-1723  03007800   USGS
# 2   STREAM-gauge-1724  03012545   USGS
# 3   STREAM-gauge-1725  03012550   USGS
# 4   STREAM-gauge-1726  03016000   USGS
# 11  STREAM-gauge-1733  03027500   USGS
#
#                                            site name  latitude_wgs84  \
# 0               Allegheny River at Port Allegany, PA       41.818676
# 2   Allegheny River below Kinzua Dam at Big Bend, PA       41.838672
# 3                  Allegheny River at Kinzua Dam, PA       41.841449
# 4                Allegheny River at West Hickory, PA       41.570895
# 11      EB Clarion River at EB Clarion River Dam, PA       41.553118
#
#     longitude_wgs84  drainagearea_sqkm    state_name time_zone  \
# 0        -78.292791         642.317520  Pennsylvania   Eastern
# 2        -79.004925        5646.178200  Pennsylvania   Eastern
# 3        -79.011985        5646.178200  Pennsylvania   Eastern
# 4        -79.407824        9479.363400  Pennsylvania   Eastern
# 11       -78.596135         189.587268  Pennsylvania   Eastern
#
#                           WQ_parameters SpC_uScm DO_mgL Turb_FNU
# 0            WTemp_C,SpC_uScm,DO_mgL,pH     True   True    False
# 2                        WTemp_C,DO_mgL    False   True    False
# 3                        WTemp_C,DO_mgL    False   True    False
# 4                      WTemp_C,SpC_uScm     True  False    False
# 11  WTemp_C,SpC_uScm,DO_mgL,pH,Turb_FNU     True   True     True

# %%
# iterate over each row and calculate
for i, row in md_wide.iterrows():
    site = row['STREAM_ID']
    wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
    q_data  = pd.read_csv(discharge_filepath+site+'.csv')
    
    # Determine distribution of flow. This should be done with a longer period of record, but for now we will leave it. 
    #bins = [0, 0.05, 0.25, 0.5, 0.75, 0.95, 100]
    bins = [0.1, 0.9]
    Q_percentiles = np.concatenate([[q_data['Q_m3s'].min()], 
                                    np.quantile(q_data['Q_m3s'], bins), 
                                    [q_data['Q_m3s'].max()]])    
    # Identify which parameters are available
    wq_params = [col for col in wq_para_data.columns 
                 if col != 'DateTime' and not col.startswith('Flag_')]
    for param in wq_params:
        wq_para_i = wq_para_data[['DateTime', param]].copy()
        wq_para_i.dropna(subset = [param], inplace=True)
        wq_para_i = wq_para_i.merge(q_data, on='DateTime', how='left')
        
        # Binning the sample flow pased on percentile 
        wq_para_i['bins'] = pd.cut(wq_para_i['Q_m3s'], 
                                   Q_percentiles,
                                   include_lowest=True)
        wq_para_i['bins'].count()
        
        # Determine distribution of params in the flow
        Q_percentiles_sample = np.quantile(wq_para_i['Q_m3s'],
                                           bins)

# %%
wq_para_i.count()
bin_count = wq_para_i['bins'].value_counts()/wq_para_i['bins'].count()
bin_count
# Out:
# bins
# (0.753, 3.652]    0.797822
# (0.546, 0.753]    0.101799
# (3.652, 4.141]    0.100379
# Name: count, dtype: float64

# %% [markdown]
# # Sampling Coverage Across Flow Regime

# %%
# Number of bins for the flow distribution (20 bins = 5% increments)
n_bins = 20
bin_edges_pct = np.linspace(0, 1, n_bins + 1)
bin_labels = [f'{int(bin_edges_pct[i]*100)}-{int(bin_edges_pct[i+1]*100)}'
              for i in range(n_bins)]

# Bulding the dataframe
results = []
missing_flow = 0
# Iterate over each row and calculate
for i, row in md_wide.iterrows():
    try:
        site = row['STREAM_ID']
        wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
        q_data  = pd.read_csv(discharge_filepath+site+'.csv')
        
        # Determine distribution of flow. This should be done with a longer period of record, but for now we will leave it. 
        Q_percentiles = np.quantile(q_data['Q_m3s'].dropna(), bin_edges_pct)
        
        # Identify which parameters are available
        wq_params = [col for col in wq_para_data.columns 
                     if col != 'DateTime' and not col.startswith('Flag_')]
        
        for param in wq_params:
            wq_para_i = wq_para_data[['DateTime', param]].copy()
            wq_para_i.dropna(subset = [param], inplace=True)
            wq_para_i = wq_para_i.merge(q_data, on='DateTime', how='left')
            wq_para_i.dropna(subset=['Q_m3s'], inplace=True)
            
            if wq_para_i.empty:
                continue
            
            # Binning the sample flow based on percentile 
            wq_para_i['bins'] = pd.cut(wq_para_i['Q_m3s'], 
                                       bins=Q_percentiles,
                                       labels=bin_labels,
                                       include_lowest=True,
                                       duplicates='drop')
            
            # Count samples per flow bin
            counts = wq_para_i['bins'].value_counts().reindex(bin_labels, fill_value=0)
            
            result_row = {
                'STREAM_ID': site,
                'param': param,
                'n_samples': int(counts.sum())
            }
            for label in bin_labels:
                result_row[label] = counts[label]
            results.append(result_row)
    except:
        missing_flow+=1  

print(f"Missing flow for {np.round((missing_flow/len(md_wide))*100,1)}% of stations.")
# Out:
# An exception occurred STREAM-gauge-1724
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (4,6,8,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# An exception occurred STREAM-gauge-1741
# An exception occurred STREAM-gauge-1742
# An exception occurred STREAM-gauge-1743
# An exception occurred STREAM-gauge-1744
# An exception occurred STREAM-gauge-1747
# An exception occurred STREAM-gauge-1751
# An exception occurred STREAM-gauge-1756
# An exception occurred STREAM-gauge-1762
# An exception occurred STREAM-gauge-1768
# An exception occurred STREAM-gauge-1769
# An exception occurred STREAM-gauge-3793
# An exception occurred STREAM-gauge-3794
# An exception occurred STREAM-gauge-3795
# An exception occurred STREAM-gauge-3796
# An exception occurred STREAM-gauge-3797
# An exception occurred STREAM-gauge-3798
# An exception occurred STREAM-gauge-3713
# An exception occurred STREAM-gauge-3799
# An exception occurred STREAM-gauge-3800
# An exception occurred STREAM-gauge-3801
# An exception occurred STREAM-gauge-3802
# An exception occurred STREAM-gauge-3803
# An exception occurred STREAM-gauge-3804
# An exception occurred STREAM-gauge-3805
# An exception occurred STREAM-gauge-3806
# An exception occurred STREAM-gauge-241
# An exception occurred STREAM-gauge-242
# An exception occurred STREAM-gauge-243
# An exception occurred STREAM-gauge-244
# An exception occurred STREAM-gauge-299
# An exception occurred STREAM-gauge-302
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (12,14,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# An exception occurred STREAM-gauge-3811
# An exception occurred STREAM-gauge-3812
# An exception occurred STREAM-gauge-3716
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# An exception occurred STREAM-gauge-3827
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (14,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# An exception occurred STREAM-gauge-3738
# An exception occurred STREAM-gauge-3745
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# An exception occurred STREAM-gauge-3749
# An exception occurred STREAM-gauge-3751
# An exception occurred STREAM-gauge-3764
# An exception occurred STREAM-gauge-3765
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (2,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# An exception occurred STREAM-gauge-2889
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (2,4,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# An exception occurred STREAM-gauge-2892
# An exception occurred STREAM-gauge-3780
# An exception occurred STREAM-gauge-2485
# An exception occurred STREAM-gauge-2486
# An exception occurred STREAM-gauge-2487
# An exception occurred STREAM-gauge-2489
# An exception occurred STREAM-gauge-2490
# An exception occurred STREAM-gauge-2491
# An exception occurred STREAM-gauge-2493
# An exception occurred STREAM-gauge-2497
# An exception occurred STREAM-gauge-2498
# An exception occurred STREAM-gauge-2499
# An exception occurred STREAM-gauge-2500
# An exception occurred STREAM-gauge-2504
# An exception occurred STREAM-gauge-2505
# An exception occurred STREAM-gauge-2507
# An exception occurred STREAM-gauge-2508
# An exception occurred STREAM-gauge-2511
# An exception occurred STREAM-gauge-57
# An exception occurred STREAM-gauge-58
# An exception occurred STREAM-gauge-61
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# An exception occurred STREAM-gauge-246
# An exception occurred STREAM-gauge-247
# An exception occurred STREAM-gauge-248
# An exception occurred STREAM-gauge-249
# An exception occurred STREAM-gauge-252
# An exception occurred STREAM-gauge-2515
# An exception occurred STREAM-gauge-2522
# An exception occurred STREAM-gauge-2524
# An exception occurred STREAM-gauge-4512
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (4,6,8,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# An exception occurred STREAM-gauge-2895
# An exception occurred STREAM-gauge-3083
# An exception occurred STREAM-gauge-3084
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# An exception occurred STREAM-gauge-2899
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# An exception occurred STREAM-gauge-4469
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# An exception occurred STREAM-gauge-2904
# An exception occurred STREAM-gauge-2905
# An exception occurred STREAM-gauge-2906
# An exception occurred STREAM-gauge-2907
# An exception occurred STREAM-gauge-2909
# An exception occurred STREAM-gauge-2912
# An exception occurred STREAM-gauge-2923
# An exception occurred STREAM-gauge-2955
# An exception occurred STREAM-gauge-2956
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (2,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# An exception occurred STREAM-gauge-2960
# An exception occurred STREAM-gauge-2961
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# An exception occurred STREAM-gauge-2991
# An exception occurred STREAM-gauge-3007
# An exception occurred STREAM-gauge-3022
# An exception occurred STREAM-gauge-4366
# An exception occurred STREAM-gauge-4373
# An exception occurred STREAM-gauge-4374
# An exception occurred STREAM-gauge-2557
# An exception occurred STREAM-gauge-679
# An exception occurred STREAM-gauge-4379
# An exception occurred STREAM-gauge-3107
# An exception occurred STREAM-gauge-2215
# An exception occurred STREAM-gauge-2218
# An exception occurred STREAM-gauge-2219
# An exception occurred STREAM-gauge-698
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# An exception occurred STREAM-gauge-2796
# An exception occurred STREAM-gauge-702
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# An exception occurred STREAM-gauge-2809
# An exception occurred STREAM-gauge-2182
# An exception occurred STREAM-gauge-2184
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (12,14,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# An exception occurred STREAM-gauge-2208
# An exception occurred STREAM-gauge-4384
# An exception occurred STREAM-gauge-4387
# An exception occurred STREAM-gauge-4388
# An exception occurred STREAM-gauge-4392
# An exception occurred STREAM-gauge-4393
# An exception occurred STREAM-gauge-2210
# An exception occurred STREAM-gauge-4394
# An exception occurred STREAM-gauge-4395
# An exception occurred STREAM-gauge-4396
# An exception occurred STREAM-gauge-4399
# An exception occurred STREAM-gauge-4405
# An exception occurred STREAM-gauge-2225
# An exception occurred STREAM-gauge-2227
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# An exception occurred STREAM-gauge-2243
# An exception occurred STREAM-gauge-2244
# An exception occurred STREAM-gauge-2819
# An exception occurred STREAM-gauge-2820
# An exception occurred STREAM-gauge-114
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (4,6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (4,6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# An exception occurred STREAM-gauge-1012
# An exception occurred STREAM-gauge-1013
# An exception occurred STREAM-gauge-4414
# An exception occurred STREAM-gauge-4418
# An exception occurred STREAM-gauge-4421
# An exception occurred STREAM-gauge-17
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (6,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# An exception occurred STREAM-gauge-27
# An exception occurred STREAM-gauge-129
# An exception occurred STREAM-gauge-1050
# An exception occurred STREAM-gauge-1051
# An exception occurred STREAM-gauge-1053
# An exception occurred STREAM-gauge-1054
# An exception occurred STREAM-gauge-1055
# An exception occurred STREAM-gauge-1056
# An exception occurred STREAM-gauge-4426
# An exception occurred STREAM-gauge-4428
# An exception occurred STREAM-gauge-4429
# An exception occurred STREAM-gauge-307
# An exception occurred STREAM-gauge-310
# An exception occurred STREAM-gauge-311
# An exception occurred STREAM-gauge-312
# An exception occurred STREAM-gauge-313
# An exception occurred STREAM-gauge-314
# An exception occurred STREAM-gauge-4559
# An exception occurred STREAM-gauge-315
# An exception occurred STREAM-gauge-316
# An exception occurred STREAM-gauge-320
# An exception occurred STREAM-gauge-321
# An exception occurred STREAM-gauge-327
# An exception occurred STREAM-gauge-331
# An exception occurred STREAM-gauge-333
# An exception occurred STREAM-gauge-334
# An exception occurred STREAM-gauge-335
# An exception occurred STREAM-gauge-336
# An exception occurred STREAM-gauge-337
# An exception occurred STREAM-gauge-338
# An exception occurred STREAM-gauge-2827
# An exception occurred STREAM-gauge-2348
# An exception occurred STREAM-gauge-2828
# An exception occurred STREAM-gauge-4477
# An exception occurred STREAM-gauge-4478
# An exception occurred STREAM-gauge-2214
# An exception occurred STREAM-gauge-2363
# An exception occurred STREAM-gauge-2364
# An exception occurred STREAM-gauge-2367
# An exception occurred STREAM-gauge-2374
# An exception occurred STREAM-gauge-1772
# An exception occurred STREAM-gauge-3845
# An exception occurred STREAM-gauge-2392
# An exception occurred STREAM-gauge-2394
# An exception occurred STREAM-gauge-703
# An exception occurred STREAM-gauge-704
# An exception occurred STREAM-gauge-705
# An exception occurred STREAM-gauge-3846
# C:\Users\danyk\AppData\Local\Temp\ipykernel_31940\1734297544.py:20: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   wq_para_data = pd.read_csv(water_quality_filepath+site+'.csv')
# An exception occurred STREAM-gauge-707
# An exception occurred STREAM-gauge-708
# An exception occurred STREAM-gauge-4480
# An exception occurred STREAM-gauge-4481
# An exception occurred STREAM-gauge-4482
# An exception occurred STREAM-gauge-4483
# An exception occurred STREAM-gauge-4484
# An exception occurred STREAM-gauge-4485
# An exception occurred STREAM-gauge-4486
# An exception occurred STREAM-gauge-2966
# An exception occurred STREAM-gauge-3110
# An exception occurred STREAM-gauge-3058
# An exception occurred STREAM-gauge-3059
# An exception occurred STREAM-gauge-3060
# An exception occurred STREAM-gauge-3061
# An exception occurred STREAM-gauge-3062
# An exception occurred STREAM-gauge-3063

# %%
# Organizing the dataframe
WQ_Q_binned_results = pd.DataFrame(results)
WQ_Q_binned_fractions = WQ_Q_binned_results[bin_labels].div(WQ_Q_binned_results['n_samples'], axis=0)*100

WQ_Q_binned_fractions.insert(0, 'STREAM_ID', df_results['STREAM_ID'])
WQ_Q_binned_fractions.insert(1, 'param', df_results['param'])
WQ_Q_binned_fractions.insert(2, 'n_samples', df_results['n_samples'])

# Expected distribution
expected = 1.0 / n_bins
print(f"The expected distribution if the sampling was evenly distributed is {expected*100}%.")

WQ_Q_binned_fractions.head()
# Out:
# The expected distribution if the sampling was evenly distributed is 5.0%.
#            STREAM_ID     param  n_samples       0-5      5-10     10-15  \
# 0  STREAM-gauge-1723   WTemp_C     114667  4.084872  3.788361  4.680510
# 1  STREAM-gauge-1723  SpC_uScm     111076  4.179121  3.673161  4.694083
# 2  STREAM-gauge-1723    DO_mgL      65212  6.526406  5.917623  7.983193
# 3  STREAM-gauge-1723        pH      68138  6.271097  5.772110  7.715225
# 4  STREAM-gauge-1725   WTemp_C      24308  9.346717  7.232187  2.279085
#
#       15-20     20-25     25-30     30-35  ...     50-55     55-60     60-65  \
# 0  4.624696  4.351732  4.680510  5.515100  ...  4.968300  5.198531  5.133997
# 1  4.610357  4.216032  4.474414  5.516043  ...  5.051496  5.192841  5.157730
# 2  7.348341  6.975710  6.682819  7.078452  ...  4.638717  3.907256  3.841318
# 3  7.144325  6.833191  6.497109  7.062139  ...  4.490886  3.849541  3.964014
# 4  5.195820  4.336021  4.442982  5.561955  ...  5.923976  5.179365  3.636663
#
#       65-70     70-75     75-80     80-85     85-90     90-95    95-100
# 0  5.331961  5.795913  5.531670  5.561321  5.050276  5.231671  4.558417
# 1  5.371097  5.688898  5.408009  5.652886  5.122619  5.341388  4.587850
# 2  4.016132  3.692572  3.036251  3.086855  2.869104  2.984113  2.525609
# 3  4.154803  3.717456  3.170037  3.215533  2.995392  3.394582  2.988054
# 4  4.726839  1.855356  6.392957  0.900938  4.870824  3.031924  2.476551
#
# [5 rows x 23 columns]

# %%
# Create heat map for each solute
params = {'DO_mgL':'DO (mg/L)',
          'SpC_uScm':'SpC (μS/cm)',
          'Turb_FNU':'Turbidity (FNU)'}
solute_summary = []
for solute, binned_sol in WQ_Q_binned_fractions.groupby('param'):
    
    # Currently sorted by STREAM ID (inherent). Uncomment to sort by high-flow sampling coverage.
    binned_sol = binned_sol.copy()
    binned_sol['sort_key'] = (binned_sol[bin_labels] - expected).abs().median(axis=1)
    binned_sol.sort_values('sort_key', ascending=False, inplace=True)
    binned_sol.drop(columns='sort_key', inplace=True)

    # Summary of results
    solute_summary_i = {
    'solute': solute,
    'n_sites': len(binned_sol),
    'median_n_samples': binned_sol['n_samples'].median(),
    'pct_below_10p': np.mean(binned_sol['0-5'] + binned_sol['5-10']), # Tail sampling
    'pct_above_90p': np.mean(binned_sol['90-95'] + binned_sol['95-100']), # Tail sampling
    'mean_abs_deviation': (binned_sol[bin_labels] - expected * 100).abs().mean().mean(), # Overall bias (how far from representative is sampling on average?)
    'pct_sites_no_highflow': ((binned_sol['90-95'] + binned_sol['95-100']) == 0).mean() * 100, # What fraction of sites have zero samples in the top 10% of flows?
    'peak_bin': binned_sol[bin_labels].median().idxmax(), # Where does the bulk of sampling concentrate?
    'pct_mid_flow': np.mean(binned_sol[mid_cols].sum(axis=1))  # Middle flow bias (what % of samples sit between 25th-75th percentile?)
    }
    solute_summary.append(solute_summary_i)
    
    # Extrating values
    plot_matrix = binned_sol[bin_labels].values
    site_labels = binned_sol['STREAM_ID'].values

    # Crating heatmap
    fig, ax = plt.subplots(figsize= (4, max(3, len(site_labels) * 0.06))) #(4,10)
    
    vmax = 20 # percent (cbar max range)
    norm = mcolors.TwoSlopeNorm(vmin=0, vcenter=expected*100, vmax=vmax) # setting max, min, and zero place
    
    im = ax.pcolormesh(plot_matrix, cmap='RdBu', norm=norm, edgecolors='none')

    # x axis aesthethic properties
    ax.set_xticks(np.arange(n_bins) + 0.5)
    ax.set_xticklabels([label if i % 2 == 0 else '' for i, label in enumerate(bin_labels)],
                   rotation=360-45, ha='center', fontsize=7)
    ax.set_xlabel('Flow Percentile Bin')

    # y axis aesthethic properties
    ax.set_yticks(np.arange(len(site_labels)) + 0.5)
    ax.set_yticklabels([])
    ax.tick_params(axis='y', length=2, width=0.5)
    ax.set_ylabel(f'Stations\n(ordered by deviation from {round(expected*100,0)}%)')

    # color bar aesthethic properties
    cbax = ax.inset_axes([1.025, 0.4, 0.03, 0.5], transform=ax.transAxes)
    cbar = fig.colorbar(im, cax=cbax, orientation='vertical')
    cbar.ax.tick_params(labelsize=7)
    cbax.set_title(f'{params_pretty_dict[solute]}', fontsize=10, pad=25, ha='left')
    cbax.text(0.0, 1.02, 'Percentage\nof samples', fontsize=7, ha='left',
          transform=cbax.transAxes, va='bottom')
    cbar.ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x:.0f}'))
    
    plt.tight_layout()
    plt.savefig(f'../OUTPUT/temporal_patterns/sampling_bias_heatmap_{solute}.png', dpi=600, bbox_inches='tight')
    #plt.show()

# %%
solute_summary_df = pd.DataFrame(solute_summary)
solute_summary_df.head(20)
