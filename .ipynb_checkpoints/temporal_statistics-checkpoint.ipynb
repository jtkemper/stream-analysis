# %% [markdown]
# # Analysis of temporal analysis
# This code was written by Sai and Danyka Byrnes

# %%
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
import seaborn as sns
import numpy as np
from config import *

from scipy.stats import gaussian_kde
from statsmodels.nonparametric.smoothers_lowess import lowess

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# #### Answer the following questions based on the timeseries data:
# 1) Percentage of data missing between the start and end date.
#
# 2) The length between start and end datetime (hour)
#
# 3) longest continous recored between the start and end date.

# %%
# List of possible parameters
parameters = [
    "WTemp_C", "SpC_uScm", "DO_mgL", "pH",
    "Turb_FNU", "Turb_NTU", "NO3_mgNL",
    "fDOM_QSU", "fDOM_RFU", "DOC_mgL",
    "PO4_mgL", "Chla_ugL", "Chla_RFU",
    "PC_ugL", "PC_RFU"
]

PARAM_COLORS = {
    'DO_mgL':    {'fill': '#FEDCBB', 'edge': '#7F2704'},
    'SpC_uScm':  {'fill': '#E2EDF8', 'edge': '#08306B'},
    'Turb_FNU':  {'fill': '#CEECC8', 'edge': '#00431A'},
}

param_pretty = {"WTemp_C":"Temp (°C)",
                "SpC_uScm":"SpC (µS/cm)",
                "DO_mgL":"DO (mg/L)",
                "pH":"pH",
                "Turb_FNU":"Turbidity (FNU)",
                "Turb_NTU":"Turbidity (NTU)",
                "NO3_mgNL":"NO₃-N (mg/L)",
                "fDOM_QSU":"fDOM (QSU)",
                "fDOM_RFU":"fDOM (RFU)",
                "DOC_mgL":"DOC (mg/L)",
                "PO4_mgL":"PO₄ (mg/L)",
                "Chla_ugL":"Chl-a (µg/L)",
                "Chla_RFU":"Chl-a (RFU)",
                "PC_ugL":"PC (µg/L)",
                "PC_RFU":"PC (RFU)",
               }

param_subset = ['SpC_uScm','DO_mgL','Turb_FNU']

# %%
# Store all results
results = []

# Loop through each CSV
for file in os.listdir(water_quality_filepath):
    if not file.endswith(".csv"):
        continue

    file_path = os.path.join(water_quality_filepath, file)
    
    # Extract STREAM_ID from filename (remove .csv)
    stream_id = os.path.splitext(file)[0]

    df = pd.read_csv(file_path, low_memory=False) # mixed data types in df, maybe worth double checking

    if "DateTime" not in df.columns:
        continue

    # Convert DateTime
    df["DateTime"] = pd.to_datetime(df["DateTime"], errors="coerce")
    df = df.sort_values("DateTime")

    station_result = {"STREAM_ID": stream_id}
    for param in parameters:
        if param in df.columns:

            df_solute = df[['DateTime', param]].dropna(subset=param)
            
            # Removing erroneous values 
            df_solute.loc[df_solute[param] < 0, param] = np.nan
            
            # Dropping NA then finding the max and min date.
            start = df_solute["DateTime"].min()
            end = df_solute["DateTime"].max()
            
            full_range = pd.date_range(start=start, end=end, freq="h")
            
            # Reindex to full hourly timeline to gapfill hours in the middle that may be empty.
            df_solute = df_solute.set_index("DateTime").reindex(full_range)
            series = df_solute[param]
            
            # 1 Length between start and end
            length_hours = len(full_range)
            
            # 2 Percentage Missing
            missing_count = series.isna().sum() # this only counts NAs in the middle of timeseries
            percent_missing = (missing_count / length_hours) * 100

            # 3 Longest continuous record (non-missing streak)
            not_na = series.notna().astype(int)
            groups = (not_na.diff() != 0).cumsum()
            streak_lengths = not_na.groupby(groups).sum()
            longest_streak = streak_lengths.max() if len(streak_lengths) > 0 else 0

            # 4  total hours available
            actual_hours = series.notna().sum()

            # 5 Seasonal gaps. 
            monthly_pct = series.groupby(series.index.to_period("M")).apply(
                lambda x: x.isna().mean() * 100)
            median_by_month = monthly_pct.groupby(monthly_pct.index.month).median()

            # The choice of replacing nan with 100 is not arbitrary. The reason I picked 100 instead of NaN is because
            # seasonal I am plotting missingness against MAT to understand whether cold-climate stations have systematic winter gaps
            median_by_month = median_by_month.reindex(range(1, 13), fill_value=100)

            # populat the list with the new summary metrics
            station_result[f"{param}_pct_missing"] = round(percent_missing, 2)
            station_result[f"{param}_length_hr"] = length_hours
            station_result[f"{param}_longest_hr"] = int(longest_streak)
            station_result[f"{param}_actual_hr"] = int(actual_hours)

            for month_num in range(1, 13):
                col = f"{param}_pct_missing_{month_num:02d}"
                if month_num in median_by_month.index:
                    station_result[col] = round(median_by_month[month_num], 2)
                else:
                    station_result[col] = np.nan

        else:
            station_result[f"{param}_pct_missing"] = np.nan
            station_result[f"{param}_length_hr"] = np.nan
            station_result[f"{param}_longest_hr"] = np.nan
            station_result[f"{param}_actual_hr"] = np.nan
            for month_num in range(1, 13):
                station_result[f"{param}_pct_missing_{month_num:02d}"] = np.nan
            
    results.append(station_result)

# Convert to dataframe
temporal_summary = pd.DataFrame(results)
temporal_summary.head()
# Out:
#            STREAM_ID  WTemp_C_pct_missing  WTemp_C_length_hr  \
# 0  STREAM-gauge-1012                40.96             8995.0
# 1  STREAM-gauge-1013                47.50             8637.0
# 2  STREAM-gauge-1014                 0.00             1456.0
# 3  STREAM-gauge-1042                 0.61             4561.0
# 4  STREAM-gauge-1043                50.22            35471.0
#
#    WTemp_C_longest_hr  WTemp_C_actual_hr  WTemp_C_pct_missing_01  \
# 0              2367.0             5311.0                   100.0
# 1              2353.0             4534.0                   100.0
# 2              1456.0             1456.0                   100.0
# 3              2625.0             4533.0                   100.0
# 4              3960.0            17657.0                   100.0
#
#    WTemp_C_pct_missing_02  WTemp_C_pct_missing_03  WTemp_C_pct_missing_04  \
# 0                   100.0                   100.0                   76.11
# 1                   100.0                   100.0                   83.06
# 2                   100.0                   100.0                  100.00
# 3                   100.0                   100.0                  100.00
# 4                   100.0                   100.0                   47.50
#
#    WTemp_C_pct_missing_05  WTemp_C_pct_missing_06  WTemp_C_pct_missing_07  \
# 0                     0.0                    0.14                    0.00
# 1                     3.9                    2.08                   36.69
# 2                   100.0                    0.00                    0.00
# 3                     0.0                    0.00                    2.02
# 4                     0.0                    0.00                    0.00
#
#    WTemp_C_pct_missing_08  WTemp_C_pct_missing_09  WTemp_C_pct_missing_10  \
# 0                    0.22                    0.00                    0.00
# 1                   13.64                    0.00                    0.00
# 2                    0.00                  100.00                  100.00
# 3                    0.00                    0.00                    0.00
# 4                    0.00                    0.07                   54.03
#
#    WTemp_C_pct_missing_11  WTemp_C_pct_missing_12  SpC_uScm_pct_missing  \
# 0                   31.94                   100.0                   NaN
# 1                   30.69                   100.0                   NaN
# 2                  100.00                   100.0                   NaN
# 3                    2.47                   100.0                  0.92
# 4                  100.00                   100.0                 50.15
#
#    SpC_uScm_length_hr  SpC_uScm_longest_hr  SpC_uScm_actual_hr  \
# 0                 NaN                  NaN                 NaN
# 1                 NaN                  NaN                 NaN
# 2                 NaN                  NaN                 NaN
# 3              4561.0               2766.0              4519.0
# 4             35471.0               4368.0             17682.0
#
#    SpC_uScm_pct_missing_01  SpC_uScm_pct_missing_02  SpC_uScm_pct_missing_03  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                    100.0                    100.0                    100.0
# 4                    100.0                    100.0                    100.0
#
#    SpC_uScm_pct_missing_04  SpC_uScm_pct_missing_05  SpC_uScm_pct_missing_06  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                    100.0                      0.0                     0.14
# 4                     47.5                      0.0                     0.00
#
#    SpC_uScm_pct_missing_07  SpC_uScm_pct_missing_08  SpC_uScm_pct_missing_09  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                     2.02                     0.00                     0.00
# 4                     0.00                     0.07                     0.07
#
#    SpC_uScm_pct_missing_10  SpC_uScm_pct_missing_11  SpC_uScm_pct_missing_12  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                     0.00                     4.93                    100.0
# 4                    54.03                   100.00                    100.0
#
#    DO_mgL_pct_missing  DO_mgL_length_hr  DO_mgL_longest_hr  DO_mgL_actual_hr  \
# 0               41.32            8994.0             1098.0            5278.0
# 1               47.47            8637.0             2353.0            4537.0
# 2                 NaN               NaN                NaN               NaN
# 3               27.52            4561.0             1555.0            3306.0
# 4               63.68           35471.0             2988.0           12884.0
#
#    DO_mgL_pct_missing_01  DO_mgL_pct_missing_02  DO_mgL_pct_missing_03  \
# 0                  100.0                  100.0                  100.0
# 1                  100.0                  100.0                  100.0
# 2                    NaN                    NaN                    NaN
# 3                  100.0                  100.0                  100.0
# 4                  100.0                  100.0                  100.0
#
#    DO_mgL_pct_missing_04  DO_mgL_pct_missing_05  DO_mgL_pct_missing_06  \
# 0                  76.11                   3.49                   0.42
# 1                  82.64                   3.90                   1.94
# 2                    NaN                    NaN                    NaN
# 3                 100.00                   0.00                  80.69
# 4                  58.82                  43.95                  35.00
#
#    DO_mgL_pct_missing_07  DO_mgL_pct_missing_08  DO_mgL_pct_missing_09  \
# 0                   0.00                   0.00                   0.14
# 1                  36.69                  13.85                   0.00
# 2                    NaN                    NaN                    NaN
# 3                  80.24                   0.00                   7.78
# 4                  17.74                  17.34                  37.08
#
#    DO_mgL_pct_missing_10  DO_mgL_pct_missing_11  DO_mgL_pct_missing_12  \
# 0                   1.48                  30.97                  100.0
# 1                   0.00                  30.69                  100.0
# 2                    NaN                    NaN                    NaN
# 3                   2.69                   0.19                  100.0
# 4                  70.83                 100.00                  100.0
#
#    pH_pct_missing  pH_length_hr  pH_longest_hr  pH_actual_hr  \
# 0           40.88        8994.0         2707.0        5317.0
# 1           50.05        8637.0         2353.0        4314.0
# 2             NaN           NaN            NaN           NaN
# 3            6.29        4561.0         2154.0        4274.0
# 4             NaN           NaN            NaN           NaN
#
#    pH_pct_missing_01  pH_pct_missing_02  pH_pct_missing_03  pH_pct_missing_04  \
# 0              100.0              100.0              100.0              76.11
# 1              100.0              100.0              100.0              93.89
# 2                NaN                NaN                NaN                NaN
# 3              100.0              100.0              100.0             100.00
# 4                NaN                NaN                NaN                NaN
#
#    pH_pct_missing_05  pH_pct_missing_06  pH_pct_missing_07  pH_pct_missing_08  \
# 0               0.00               0.14               0.00               0.00
# 1              22.85               2.08              36.69              13.85
# 2                NaN                NaN                NaN                NaN
# 3               0.00               0.28              38.17               0.00
# 4                NaN                NaN                NaN                NaN
#
#    pH_pct_missing_09  pH_pct_missing_10  pH_pct_missing_11  pH_pct_missing_12  \
# 0                0.0               0.00              31.11              100.0
# 1                0.0               0.00              30.69              100.0
# 2                NaN                NaN                NaN                NaN
# 3                0.0               0.13               0.00              100.0
# 4                NaN                NaN                NaN                NaN
#
#    Turb_FNU_pct_missing  Turb_FNU_length_hr  Turb_FNU_longest_hr  \
# 0                 51.43              8994.0               1906.0
# 1                 49.10              8637.0               2254.0
# 2                   NaN                 NaN                  NaN
# 3                 17.20              3965.0                590.0
# 4                 63.48             35471.0                960.0
#
#    Turb_FNU_actual_hr  Turb_FNU_pct_missing_01  Turb_FNU_pct_missing_02  \
# 0              4368.0                    100.0                    100.0
# 1              4396.0                    100.0                    100.0
# 2                 NaN                      NaN                      NaN
# 3              3283.0                    100.0                    100.0
# 4             12955.0                    100.0                    100.0
#
#    Turb_FNU_pct_missing_03  Turb_FNU_pct_missing_04  Turb_FNU_pct_missing_05  \
# 0                    100.0                    76.11                     5.78
# 1                    100.0                    82.50                    21.51
# 2                      NaN                      NaN                      NaN
# 3                    100.0                   100.00                   100.00
# 4                    100.0                    47.50                    27.82
#
#    Turb_FNU_pct_missing_06  Turb_FNU_pct_missing_07  Turb_FNU_pct_missing_08  \
# 0                    14.58                     0.07                     0.00
# 1                     2.08                    36.69                    13.85
# 2                      NaN                      NaN                      NaN
# 3                     0.00                    23.12                    34.68
# 4                    14.65                    33.87                    40.52
#
#    Turb_FNU_pct_missing_09  Turb_FNU_pct_missing_10  Turb_FNU_pct_missing_11  \
# 0                     0.00                    40.99                   100.00
# 1                     0.00                     0.00                    32.08
# 2                      NaN                      NaN                      NaN
# 3                     6.67                    25.40                     2.85
# 4                    27.50                    74.08                   100.00
#
#    Turb_FNU_pct_missing_12  Turb_NTU_pct_missing  Turb_NTU_length_hr  \
# 0                    100.0                   NaN                 NaN
# 1                    100.0                   NaN                 NaN
# 2                      NaN                   NaN                 NaN
# 3                    100.0                   NaN                 NaN
# 4                    100.0                   NaN                 NaN
#
#    Turb_NTU_longest_hr  Turb_NTU_actual_hr  Turb_NTU_pct_missing_01  \
# 0                  NaN                 NaN                      NaN
# 1                  NaN                 NaN                      NaN
# 2                  NaN                 NaN                      NaN
# 3                  NaN                 NaN                      NaN
# 4                  NaN                 NaN                      NaN
#
#    Turb_NTU_pct_missing_02  Turb_NTU_pct_missing_03  Turb_NTU_pct_missing_04  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    Turb_NTU_pct_missing_05  Turb_NTU_pct_missing_06  Turb_NTU_pct_missing_07  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    Turb_NTU_pct_missing_08  Turb_NTU_pct_missing_09  Turb_NTU_pct_missing_10  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    Turb_NTU_pct_missing_11  Turb_NTU_pct_missing_12  NO3_mgNL_pct_missing  \
# 0                      NaN                      NaN                   NaN
# 1                      NaN                      NaN                   NaN
# 2                      NaN                      NaN                   NaN
# 3                      NaN                      NaN                   NaN
# 4                      NaN                      NaN                   NaN
#
#    NO3_mgNL_length_hr  NO3_mgNL_longest_hr  NO3_mgNL_actual_hr  \
# 0                 NaN                  NaN                 NaN
# 1                 NaN                  NaN                 NaN
# 2                 NaN                  NaN                 NaN
# 3                 NaN                  NaN                 NaN
# 4                 NaN                  NaN                 NaN
#
#    NO3_mgNL_pct_missing_01  NO3_mgNL_pct_missing_02  NO3_mgNL_pct_missing_03  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    NO3_mgNL_pct_missing_04  NO3_mgNL_pct_missing_05  NO3_mgNL_pct_missing_06  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    NO3_mgNL_pct_missing_07  NO3_mgNL_pct_missing_08  NO3_mgNL_pct_missing_09  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    NO3_mgNL_pct_missing_10  NO3_mgNL_pct_missing_11  NO3_mgNL_pct_missing_12  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    fDOM_QSU_pct_missing  fDOM_QSU_length_hr  fDOM_QSU_longest_hr  \
# 0                   NaN                 NaN                  NaN
# 1                   NaN                 NaN                  NaN
# 2                   NaN                 NaN                  NaN
# 3                   NaN                 NaN                  NaN
# 4                   NaN                 NaN                  NaN
#
#    fDOM_QSU_actual_hr  fDOM_QSU_pct_missing_01  fDOM_QSU_pct_missing_02  \
# 0                 NaN                      NaN                      NaN
# 1                 NaN                      NaN                      NaN
# 2                 NaN                      NaN                      NaN
# 3                 NaN                      NaN                      NaN
# 4                 NaN                      NaN                      NaN
#
#    fDOM_QSU_pct_missing_03  fDOM_QSU_pct_missing_04  fDOM_QSU_pct_missing_05  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    fDOM_QSU_pct_missing_06  fDOM_QSU_pct_missing_07  fDOM_QSU_pct_missing_08  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    fDOM_QSU_pct_missing_09  fDOM_QSU_pct_missing_10  fDOM_QSU_pct_missing_11  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    fDOM_QSU_pct_missing_12  fDOM_RFU_pct_missing  fDOM_RFU_length_hr  \
# 0                      NaN                   NaN                 NaN
# 1                      NaN                   NaN                 NaN
# 2                      NaN                   NaN                 NaN
# 3                      NaN                   NaN                 NaN
# 4                      NaN                   NaN                 NaN
#
#    fDOM_RFU_longest_hr  fDOM_RFU_actual_hr  fDOM_RFU_pct_missing_01  \
# 0                  NaN                 NaN                      NaN
# 1                  NaN                 NaN                      NaN
# 2                  NaN                 NaN                      NaN
# 3                  NaN                 NaN                      NaN
# 4                  NaN                 NaN                      NaN
#
#    fDOM_RFU_pct_missing_02  fDOM_RFU_pct_missing_03  fDOM_RFU_pct_missing_04  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    fDOM_RFU_pct_missing_05  fDOM_RFU_pct_missing_06  fDOM_RFU_pct_missing_07  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    fDOM_RFU_pct_missing_08  fDOM_RFU_pct_missing_09  fDOM_RFU_pct_missing_10  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    fDOM_RFU_pct_missing_11  fDOM_RFU_pct_missing_12  DOC_mgL_pct_missing  \
# 0                      NaN                      NaN                  NaN
# 1                      NaN                      NaN                  NaN
# 2                      NaN                      NaN                  NaN
# 3                      NaN                      NaN                  NaN
# 4                      NaN                      NaN                  NaN
#
#    DOC_mgL_length_hr  DOC_mgL_longest_hr  DOC_mgL_actual_hr  \
# 0                NaN                 NaN                NaN
# 1                NaN                 NaN                NaN
# 2                NaN                 NaN                NaN
# 3                NaN                 NaN                NaN
# 4                NaN                 NaN                NaN
#
#    DOC_mgL_pct_missing_01  DOC_mgL_pct_missing_02  DOC_mgL_pct_missing_03  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
# 2                     NaN                     NaN                     NaN
# 3                     NaN                     NaN                     NaN
# 4                     NaN                     NaN                     NaN
#
#    DOC_mgL_pct_missing_04  DOC_mgL_pct_missing_05  DOC_mgL_pct_missing_06  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
# 2                     NaN                     NaN                     NaN
# 3                     NaN                     NaN                     NaN
# 4                     NaN                     NaN                     NaN
#
#    DOC_mgL_pct_missing_07  DOC_mgL_pct_missing_08  DOC_mgL_pct_missing_09  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
# 2                     NaN                     NaN                     NaN
# 3                     NaN                     NaN                     NaN
# 4                     NaN                     NaN                     NaN
#
#    DOC_mgL_pct_missing_10  DOC_mgL_pct_missing_11  DOC_mgL_pct_missing_12  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
# 2                     NaN                     NaN                     NaN
# 3                     NaN                     NaN                     NaN
# 4                     NaN                     NaN                     NaN
#
#    PO4_mgL_pct_missing  PO4_mgL_length_hr  PO4_mgL_longest_hr  \
# 0                  NaN                NaN                 NaN
# 1                  NaN                NaN                 NaN
# 2                  NaN                NaN                 NaN
# 3                  NaN                NaN                 NaN
# 4                  NaN                NaN                 NaN
#
#    PO4_mgL_actual_hr  PO4_mgL_pct_missing_01  PO4_mgL_pct_missing_02  \
# 0                NaN                     NaN                     NaN
# 1                NaN                     NaN                     NaN
# 2                NaN                     NaN                     NaN
# 3                NaN                     NaN                     NaN
# 4                NaN                     NaN                     NaN
#
#    PO4_mgL_pct_missing_03  PO4_mgL_pct_missing_04  PO4_mgL_pct_missing_05  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
# 2                     NaN                     NaN                     NaN
# 3                     NaN                     NaN                     NaN
# 4                     NaN                     NaN                     NaN
#
#    PO4_mgL_pct_missing_06  PO4_mgL_pct_missing_07  PO4_mgL_pct_missing_08  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
# 2                     NaN                     NaN                     NaN
# 3                     NaN                     NaN                     NaN
# 4                     NaN                     NaN                     NaN
#
#    PO4_mgL_pct_missing_09  PO4_mgL_pct_missing_10  PO4_mgL_pct_missing_11  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
# 2                     NaN                     NaN                     NaN
# 3                     NaN                     NaN                     NaN
# 4                     NaN                     NaN                     NaN
#
#    PO4_mgL_pct_missing_12  Chla_ugL_pct_missing  Chla_ugL_length_hr  \
# 0                     NaN                   NaN                 NaN
# 1                     NaN                   NaN                 NaN
# 2                     NaN                   NaN                 NaN
# 3                     NaN                   NaN                 NaN
# 4                     NaN                   NaN                 NaN
#
#    Chla_ugL_longest_hr  Chla_ugL_actual_hr  Chla_ugL_pct_missing_01  \
# 0                  NaN                 NaN                      NaN
# 1                  NaN                 NaN                      NaN
# 2                  NaN                 NaN                      NaN
# 3                  NaN                 NaN                      NaN
# 4                  NaN                 NaN                      NaN
#
#    Chla_ugL_pct_missing_02  Chla_ugL_pct_missing_03  Chla_ugL_pct_missing_04  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    Chla_ugL_pct_missing_05  Chla_ugL_pct_missing_06  Chla_ugL_pct_missing_07  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    Chla_ugL_pct_missing_08  Chla_ugL_pct_missing_09  Chla_ugL_pct_missing_10  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    Chla_ugL_pct_missing_11  Chla_ugL_pct_missing_12  Chla_RFU_pct_missing  \
# 0                      NaN                      NaN                   NaN
# 1                      NaN                      NaN                   NaN
# 2                      NaN                      NaN                   NaN
# 3                      NaN                      NaN                   NaN
# 4                      NaN                      NaN                   NaN
#
#    Chla_RFU_length_hr  Chla_RFU_longest_hr  Chla_RFU_actual_hr  \
# 0                 NaN                  NaN                 NaN
# 1                 NaN                  NaN                 NaN
# 2                 NaN                  NaN                 NaN
# 3                 NaN                  NaN                 NaN
# 4                 NaN                  NaN                 NaN
#
#    Chla_RFU_pct_missing_01  Chla_RFU_pct_missing_02  Chla_RFU_pct_missing_03  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    Chla_RFU_pct_missing_04  Chla_RFU_pct_missing_05  Chla_RFU_pct_missing_06  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    Chla_RFU_pct_missing_07  Chla_RFU_pct_missing_08  Chla_RFU_pct_missing_09  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    Chla_RFU_pct_missing_10  Chla_RFU_pct_missing_11  Chla_RFU_pct_missing_12  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    PC_ugL_pct_missing  PC_ugL_length_hr  PC_ugL_longest_hr  PC_ugL_actual_hr  \
# 0                 NaN               NaN                NaN               NaN
# 1                 NaN               NaN                NaN               NaN
# 2                 NaN               NaN                NaN               NaN
# 3                 NaN               NaN                NaN               NaN
# 4                 NaN               NaN                NaN               NaN
#
#    PC_ugL_pct_missing_01  PC_ugL_pct_missing_02  PC_ugL_pct_missing_03  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#    PC_ugL_pct_missing_04  PC_ugL_pct_missing_05  PC_ugL_pct_missing_06  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#    PC_ugL_pct_missing_07  PC_ugL_pct_missing_08  PC_ugL_pct_missing_09  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#    PC_ugL_pct_missing_10  PC_ugL_pct_missing_11  PC_ugL_pct_missing_12  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#    PC_RFU_pct_missing  PC_RFU_length_hr  PC_RFU_longest_hr  PC_RFU_actual_hr  \
# 0                 NaN               NaN                NaN               NaN
# 1                 NaN               NaN                NaN               NaN
# 2                 NaN               NaN                NaN               NaN
# 3                 NaN               NaN                NaN               NaN
# 4                 NaN               NaN                NaN               NaN
#
#    PC_RFU_pct_missing_01  PC_RFU_pct_missing_02  PC_RFU_pct_missing_03  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#    PC_RFU_pct_missing_04  PC_RFU_pct_missing_05  PC_RFU_pct_missing_06  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#    PC_RFU_pct_missing_07  PC_RFU_pct_missing_08  PC_RFU_pct_missing_09  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#    PC_RFU_pct_missing_10  PC_RFU_pct_missing_11  PC_RFU_pct_missing_12
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN

# %%
# Merging the temporal data derived by Sai
# Identify ID/metadata columns (keep these as-is)
id_cols = ['STREAM_ID']

# Reshape
rows = []
for temp_param in parameters:
    temp = temporal_summary[id_cols].copy()
    temp['parameter'] = temp_param
    temp['pct_missing'] = temporal_summary[f'{temp_param}_pct_missing']
    temp['length_hr'] = temporal_summary[f'{temp_param}_length_hr']
    temp['longest_hr'] = temporal_summary[f'{temp_param}_longest_hr']
    temp['actual_hr'] = temporal_summary[f'{temp_param}_actual_hr']

    # This parameter is the median percentage of the months across the record period that is missing data data. 
    # If the value is 100, it means that in at least one year, that month was in the timeseries, but it missing data
    # If the value is NaN, then the month never appeared in the timeseries.
    for month_num in range(1, 13):
        temp[f'pct_missing_{month_num:02d}'] = temporal_summary[f'{temp_param}_pct_missing_{month_num:02d}']
    rows.append(temp)

temporal_summary_long = (
    pd.concat(rows, ignore_index=True)
    .query('parameter in @parameters')
    .dropna(how='all', subset=['pct_missing', 'length_hr', 'longest_hr', 'actual_hr'])
)

temporal_summary_long.to_csv(OUTPUT_filepath+'temporal_statistics.csv', index=False)

# %%
# For now, just set 100 and NaNs both to 100 because I feel like these are corner cases. 
month_cols = [f'pct_missing_{m:02d}' for m in range(1, 13)]
temporal_summary_long[month_cols] = temporal_summary_long[month_cols].replace(np.nan, 100)

temporal_summary_long.head()
# Out:
#            STREAM_ID parameter  pct_missing  length_hr  longest_hr  actual_hr  \
# 0  STREAM-gauge-1012   WTemp_C        40.96     8995.0      2367.0     5311.0
# 1  STREAM-gauge-1013   WTemp_C        47.50     8637.0      2353.0     4534.0
# 2  STREAM-gauge-1014   WTemp_C         0.00     1456.0      1456.0     1456.0
# 3  STREAM-gauge-1042   WTemp_C         0.61     4561.0      2625.0     4533.0
# 4  STREAM-gauge-1043   WTemp_C        50.22    35471.0      3960.0    17657.0
#
#    pct_missing_01  pct_missing_02  pct_missing_03  pct_missing_04  \
# 0           100.0           100.0           100.0           76.11
# 1           100.0           100.0           100.0           83.06
# 2           100.0           100.0           100.0          100.00
# 3           100.0           100.0           100.0          100.00
# 4           100.0           100.0           100.0           47.50
#
#    pct_missing_05  pct_missing_06  pct_missing_07  pct_missing_08  \
# 0             0.0            0.14            0.00            0.22
# 1             3.9            2.08           36.69           13.64
# 2           100.0            0.00            0.00            0.00
# 3             0.0            0.00            2.02            0.00
# 4             0.0            0.00            0.00            0.00
#
#    pct_missing_09  pct_missing_10  pct_missing_11  pct_missing_12
# 0            0.00            0.00           31.94           100.0
# 1            0.00            0.00           30.69           100.0
# 2          100.00          100.00          100.00           100.0
# 3            0.00            0.00            2.47           100.0
# 4            0.07           54.03          100.00           100.0

# %%
# Also creating a dataframe that treats station and each year as an individual datapoint
# This repeats the previous block's code to improve the readability of the code. 
results = []

# Loop through each CSV
for file in os.listdir(water_quality_filepath):
    if not file.endswith(".csv"):
        continue

    file_path = os.path.join(water_quality_filepath, file)
    
    # Extract STREAM_ID from filename (remove .csv)
    stream_id = os.path.splitext(file)[0]

    df = pd.read_csv(file_path, low_memory=False) # mixed data types in df, maybe worth double checking

    if "DateTime" not in df.columns:
        continue

    # Convert DateTime
    df["DateTime"] = pd.to_datetime(df["DateTime"], errors="coerce")
    df = df.sort_values("DateTime")

    station_result = {"STREAM_ID": stream_id}
    for param in parameters:
        if param in df.columns:

            df_solute = df[['DateTime', param]].dropna(subset=param)
            
            # Removing erroneous values 
            df_solute.loc[df_solute[param] < 0, param] = np.nan
            
            # Dropping NA then finding the max and min date.
            start = df_solute["DateTime"].min()
            end = df_solute["DateTime"].max()
            
            full_range = pd.date_range(start=start, end=end, freq="h")
            
            # Reindex to full hourly timeline to gapfill hours in the middle that may be empty.
            df_solute = df_solute.set_index("DateTime").reindex(full_range)
            monthly_pct = df_solute[param].groupby([df_solute.index.year, df_solute.index.month]).apply(
                lambda x: x.isna().mean() * 100
            )
            for (year, month), val in monthly_pct.items():
                results.append({
                    'STREAM_ID': stream_id,
                    'parameter': param,
                    'year': int(year),
                    'month': int(month),
                    'pct_missing': round(val, 2)
                })
                
    results.append(station_result)

# Convert to dataframe
monthly_summary = pd.DataFrame(results)
monthly_summary.head()
# Out:
#            STREAM_ID parameter    year  month  pct_missing
# 0  STREAM-gauge-1012   WTemp_C  2024.0    7.0         0.00
# 1  STREAM-gauge-1012   WTemp_C  2024.0    8.0         0.00
# 2  STREAM-gauge-1012   WTemp_C  2024.0    9.0         0.00
# 3  STREAM-gauge-1012   WTemp_C  2024.0   10.0         0.00
# 4  STREAM-gauge-1012   WTemp_C  2024.0   11.0        31.94

# %%
# Also creating a dataframe that has the daily data avalability for each station. Just station ID, Year, Month, and day. 
# This again repeats the previous block's code to improve the readability of the code. 
results = []

# Loop through each CSV
for file in os.listdir(water_quality_filepath):
    if not file.endswith(".csv"):
        continue

    file_path = os.path.join(water_quality_filepath, file)
    stream_id = os.path.splitext(file)[0]

    df = pd.read_csv(file_path, low_memory=False)

    if "DateTime" not in df.columns:
        continue

    df["DateTime"] = pd.to_datetime(df["DateTime"], errors="coerce")
    df = df.sort_values("DateTime")

    for param in parameters:  # <-- indented inside the file loop
        if param in df.columns:
            df_solute = df[['DateTime', param]].dropna(subset=[param])
            df_solute.loc[df_solute[param] < 0, param] = np.nan
            df_solute = df_solute.dropna(subset=[param])

            temp = pd.DataFrame({
                'STREAM_ID': stream_id,
                'parameter': param,
                'date': df_solute['DateTime'],
                'year': df_solute['DateTime'].dt.year,
                'month': df_solute['DateTime'].dt.month,
                'day': df_solute['DateTime'].dt.day,
                'hour': df_solute['DateTime'].dt.hour
            })
            results.append(temp)

hourly_summary = pd.concat(results, ignore_index=True)
hourly_summary.head()
# Out:
#            STREAM_ID parameter                date  year  month  day  hour
# 0  STREAM-gauge-1012   WTemp_C 2024-07-31 20:00:00  2024      7   31    20
# 1  STREAM-gauge-1012   WTemp_C 2024-07-31 21:00:00  2024      7   31    21
# 2  STREAM-gauge-1012   WTemp_C 2024-07-31 22:00:00  2024      7   31    22
# 3  STREAM-gauge-1012   WTemp_C 2024-07-31 23:00:00  2024      7   31    23
# 4  STREAM-gauge-1012   WTemp_C 2024-08-01 00:00:00  2024      8    1     0

# %%
# Processing metadata, isolating specific parameters
md_wide = pd.read_csv(metadata_filepath+"metadata.csv", dtype = {'sourceID': str})
print(f"Full dataset size: {md_wide.shape[0]}")

for param in param_subset:
    md_wide[param] = md_wide['WQ_parameters'].str.contains(param)

# Removing the stations without data
md_wide = md_wide[(md_wide['SpC_uScm']) | (md_wide['DO_mgL']) | (md_wide['Turb_FNU'])]
print(f"Filtered dataset size: {md_wide.shape[0]}")
# Out:
# Full dataset size: 870
# Filtered dataset size: 556

# %% [markdown]
# ## Temporal Gaps (Where are the gaps over time?)

# %%
daily_summary_results = []
for param in param_subset:
    param_hourly_summary = hourly_summary[hourly_summary['parameter'] == param]
    param_daily_occur = param_hourly_summary.groupby(['year', 'month', 'day'])['STREAM_ID'].nunique().reset_index()
    param_daily_occur.columns = ['year', 'month', 'day', 'n_stations']
    param_daily_occur['parameter'] = param
    daily_summary_results.append(param_daily_occur)

daily_occurrence = pd.concat(daily_summary_results, ignore_index=True)
datetime_components_dict = {
    'year': daily_occurrence['year'],
    'month': daily_occurrence['month'],
    'day': daily_occurrence['day']
}

daily_occurrence['DateTime'] = pd.to_datetime(datetime_components_dict)
daily_occurrence.head()
# Out:
#    year  month  day  n_stations parameter   DateTime
# 0  2006      4   27           2  SpC_uScm 2006-04-27
# 1  2006      4   28           2  SpC_uScm 2006-04-28
# 2  2006      4   29           2  SpC_uScm 2006-04-29
# 3  2006      4   30           2  SpC_uScm 2006-04-30
# 4  2006      5    1           2  SpC_uScm 2006-05-01

# %%
hourly_summary_results = []
for param in param_subset:
    param_hourly_summary = hourly_summary[hourly_summary['parameter'] == param]
    param_hourly_occur = param_hourly_summary.groupby(['hour']).size().reset_index(name='n_obs')
    param_hourly_occur.columns = ['hour', 'n_obs']
    param_hourly_occur['pct'] = param_hourly_occur['n_obs'] / param_hourly_occur['n_obs'].sum() * 100
    param_hourly_occur['parameter'] = param
    hourly_summary_results.append(param_hourly_occur)

hourly_occurrence = pd.concat(hourly_summary_results, ignore_index=True)
hourly_occurrence.head()
# Out:
#    hour    n_obs       pct parameter
# 0     0  1097214  4.170018  SpC_uScm
# 1     1  1097289  4.170303  SpC_uScm
# 2     2  1097367  4.170600  SpC_uScm
# 3     3  1097140  4.169737  SpC_uScm
# 4     4  1097227  4.170068  SpC_uScm

# %%
fig, axes = plt.subplots(3, 1, figsize=(7, 3), sharex=True)

for i, param in enumerate(param_subset):
    param_data = daily_occurrence[daily_occurrence['parameter'] == param]
    
    axes[i].fill_between(param_data['DateTime'], param_data['n_stations'],
                         color=PARAM_COLORS[param]['fill'], alpha=0.7,
                         edgecolor=PARAM_COLORS[param]['edge'], linewidth=0.5)
    if i == 1:
        axes[i].set_ylabel('No. of stations')
    else:
        axes[i].set_ylabel('')
        
    axes[i].set_ylim(0, 250)
    axes[i].set_xlim(param_data['DateTime'].min(), param_data['DateTime'].max())
    
    axes[i].text(1, 1.07, param_pretty[param], transform=axes[i].transAxes,
                 ha='right', fontsize=10)
    
    axes[i].spines['top'].set_visible(False)
    axes[i].spines['right'].set_visible(False)
    axes[i].spines['bottom'].set_visible(False)
    axes[i].spines['left'].set_visible(False)
    axes[i].tick_params(axis='x', which='minor', bottom=True)

fig.tight_layout()
plt.savefig(f'../OUTPUT/temporal_patterns/parameter_no_of_stations_year.png', dpi=600, bbox_inches='tight')

# %%
fig, axes = plt.subplots(1, 3, figsize=(9, 2.5), sharey=True)

for i, param in enumerate(param_subset):
    param_data = hourly_occurrence[hourly_occurrence['parameter'] == param]
    
    axes[i].bar(param_data['hour'], param_data['pct'],
                color=PARAM_COLORS[param]['fill'],
                edgecolor=PARAM_COLORS[param]['edge'],
                linewidth=0.5)
    
    axes[i].set_xlabel('Hour of day')
    axes[i].set_ylabel('% of observations' if i == 0 else '')
    axes[i].set_xticks(range(0, 24, 3))
    axes[i].text(0.97, 1.05, param_pretty[param], transform=axes[i].transAxes,
                 ha='right', fontsize=9)
    axes[i].spines['top'].set_visible(False)
    axes[i].spines['right'].set_visible(False)
    axes[i].spines['bottom'].set_visible(False)
    axes[i].spines['left'].set_visible(False)

fig.tight_layout()
plt.savefig(f'../OUTPUT/temporal_patterns/parameter_percent_observation_hour.png', dpi=600, bbox_inches='tight')

# %% [markdown]
# ## Seasonal Gaps

# %% [markdown]
# ### Where are the seasonal gaps?

# %%
temporal_summary_long.head(3)
# Out:
#              STREAM_ID parameter  pct_missing  length_hr  longest_hr  \
# 872  STREAM-gauge-1042  SpC_uScm         0.92     4561.0      2766.0
# 873  STREAM-gauge-1043  SpC_uScm        50.15    35471.0      4368.0
# 874  STREAM-gauge-1044  SpC_uScm         2.73     1464.0      1319.0
#
#      actual_hr  pct_missing_01  pct_missing_02  pct_missing_03  \
# 872     4519.0           100.0           100.0           100.0
# 873    17682.0           100.0           100.0           100.0
# 874     1424.0           100.0           100.0           100.0
#
#      pct_missing_04  pct_missing_05  pct_missing_06  pct_missing_07  \
# 872           100.0             0.0            0.14            2.02
# 873            47.5             0.0            0.00            0.00
# 874           100.0           100.0            0.00            0.00
#
#      pct_missing_08  pct_missing_09  pct_missing_10  pct_missing_11  \
# 872            0.00            0.00            0.00            4.93
# 873            0.07            0.07           54.03          100.00
# 874           16.88          100.00          100.00          100.00
#
#      pct_missing_12
# 872           100.0
# 873           100.0
# 874           100.0

# %%
# What is the frequency of stations with no data, per month. 
# Using the median (across years) percent of missing data per month for each individual station.
month_cols = [f'pct_missing_{m:02d}' for m in range(1, 13)]
month_labels = ['Ja','F','Mr','Ap','Ma','Jn','Jl','Au','S','O','N','D']

fig, axes = plt.subplots(1, 3, figsize=(9, 2.5), sharey=True)

for i, param in enumerate(param_subset):
    temp_data_p = temporal_summary_long[temporal_summary_long['parameter'] == param]
    n_stations = len(temp_data_p)
    
    freq_100 = [(100-(temp_data_p[mcol] == 100).sum() / n_stations * 100) for mcol in month_cols]
    axes[i].bar(month_labels, freq_100, color=PARAM_COLORS[param]['fill'], edgecolor=PARAM_COLORS[param]['edge'])
    axes[i].set_ylabel('% of stations with data' if i == 0 else '',fontsize=9)
    axes[i].tick_params(axis='x', rotation=0, labelsize=8)
    axes[i].set_ylim(0, 100)
    axes[i].text(11.75, 92, param_pretty[param], horizontalalignment='right')

fig.tight_layout()
plt.savefig(f'../OUTPUT/temporal_patterns/parameter_percent_station_data.png', dpi=600, bbox_inches='tight')

# %%
monthly_summary.head()
# Out:
#            STREAM_ID parameter    year  month  pct_missing
# 0  STREAM-gauge-1012   WTemp_C  2024.0    7.0         0.00
# 1  STREAM-gauge-1012   WTemp_C  2024.0    8.0         0.00
# 2  STREAM-gauge-1012   WTemp_C  2024.0    9.0         0.00
# 3  STREAM-gauge-1012   WTemp_C  2024.0   10.0         0.00
# 4  STREAM-gauge-1012   WTemp_C  2024.0   11.0        31.94

# %%
# What is the distribution of records gaps per month per solute?
month_labels = ['Ja','F','Mr','Ap','Ma','Jn','Jl','Au','S','O','N','D']
fig, axes = plt.subplots(1, 3, figsize=(9, 2.5), sharey=True)

for i, param in enumerate(param_subset):
    temp_data_p = monthly_summary[monthly_summary['parameter'] == param]
    
    # Categorize each station-year-month
    temp_data_p = temp_data_p.copy()
    
    # Binning the data 
    temp_data_p['category'] = pd.cut(
        temp_data_p['pct_missing'], 
        bins=[-0.1, 0, 50, 99.9, 100],
        labels=['Complete', 'Partial (1-50%)', 'Partial (51-99%)', 'No data']
    )

    # For each station-year, count the frequency of each bin per month.
    counts = temp_data_p.groupby(['month', 'category'], observed=False).size().unstack(fill_value=0)
    fractions = counts.div(counts.sum(axis=1), axis=0) * 100
        
    # Create color gradient: darkest for "no data", lightest for "complete"
    edge = PARAM_COLORS[param]['edge'] 
    colors = [edge, edge, edge, edge]
    alphas = [0.2, 0.4, 0.6, 0.9]

    # Creating a stacked bar plot by addding the bins cumulatively.
    bottom = np.zeros(12)
    categories = ['Complete', 'Partial (1-50%)', 'Partial (51-99%)', 'No data']
    for j, cat in enumerate(categories):
        if cat in fractions.columns:
            vals = fractions[cat].values
            axes[i].bar(range(12), vals, bottom=bottom, 
                       color=colors[j], alpha=alphas[j], 
                       edgecolor=edge, linewidth=1)
            bottom += vals

    # Aesthetic properties
    axes[i].set_ylabel('% of station-years' if i == 0 else '', fontsize=9)
    axes[i].set_xlabel('')
    axes[i].tick_params(axis='x', rotation=0, labelsize=8)
    axes[i].set_xticks(range(12))
    axes[i].set_xticklabels(month_labels)
    axes[i].set_ylim(-5, 110)
    axes[i].text(11.8, 102, param_pretty[param], horizontalalignment='right', fontsize=9)

# Add legend
legend_elements = [
    Patch(facecolor='grey', alpha=0.1, edgecolor='black', label='Complete'),
    Patch(facecolor='grey', alpha=0.3, edgecolor='black', label='Partial (1-50%)'),
    Patch(facecolor='grey', alpha=0.6, edgecolor='black', label='Partial (51-99%)'),
    Patch(facecolor='grey', alpha=0.9, edgecolor='black', label='No data'),
]
fig.legend(handles=legend_elements, loc='lower center', ncol=4, fontsize=7, 
           bbox_to_anchor=(0.5, -0.12))

fig.tight_layout()
plt.savefig(f'../OUTPUT/temporal_patterns/monthly_station_year_record_completeness_distribution.png', dpi=600, bbox_inches='tight')

# %% [markdown]
# ### The relationship between mean annual temperature and gaps

# %%
# Reading and filtering 
basinatlas = pd.read_csv(basin_atlas_filepath+"static_basinatlas_catchment_characteristics.csv")
basinatlas = basinatlas[['STREAM_ID',
                         'tmp_dc_syr', # mean annual temperature
                        ]]

param_dict = {'tmp_dc_syr':'MAT'}

# Converting to true values
basinatlas['tmp_dc_syr'] = basinatlas['tmp_dc_syr']/10

# merging MAT with temporal variables
temperature_data = pd.merge(temporal_summary_long, basinatlas, on='STREAM_ID', how='left')
monthly_temperature_summary = pd.merge(monthly_summary, basinatlas, on='STREAM_ID', how='left')

temperature_data.head()
# Out:
#            STREAM_ID parameter  pct_missing  length_hr  longest_hr  actual_hr  \
# 0  STREAM-gauge-1012   WTemp_C        40.96     8995.0      2367.0     5311.0
# 1  STREAM-gauge-1013   WTemp_C        47.50     8637.0      2353.0     4534.0
# 2  STREAM-gauge-1014   WTemp_C         0.00     1456.0      1456.0     1456.0
# 3  STREAM-gauge-1042   WTemp_C         0.61     4561.0      2625.0     4533.0
# 4  STREAM-gauge-1043   WTemp_C        50.22    35471.0      3960.0    17657.0
#
#    pct_missing_01  pct_missing_02  pct_missing_03  pct_missing_04  \
# 0           100.0           100.0           100.0           76.11
# 1           100.0           100.0           100.0           83.06
# 2           100.0           100.0           100.0          100.00
# 3           100.0           100.0           100.0          100.00
# 4           100.0           100.0           100.0           47.50
#
#    pct_missing_05  pct_missing_06  pct_missing_07  pct_missing_08  \
# 0             0.0            0.14            0.00            0.22
# 1             3.9            2.08           36.69           13.64
# 2           100.0            0.00            0.00            0.00
# 3             0.0            0.00            2.02            0.00
# 4             0.0            0.00            0.00            0.00
#
#    pct_missing_09  pct_missing_10  pct_missing_11  pct_missing_12  tmp_dc_syr
# 0            0.00            0.00           31.94           100.0    4.197165
# 1            0.00            0.00           30.69           100.0    6.800000
# 2          100.00          100.00          100.00           100.0   14.073459
# 3            0.00            0.00            2.47           100.0    5.957540
# 4            0.07           54.03          100.00           100.0    7.554231

# %%
# Plotting temporal variables against temperature. 
for param in param_subset:
    # First drop the variables we are not looking at.
    temp_data_p = temperature_data[temperature_data['parameter'].isin([param])]
    # Plot the solutes we are
    fig, axes = plt.subplots(1,3, figsize=(7, 2))
    axes[0].scatter(temp_data_p['tmp_dc_syr'], temp_data_p['length_hr']/24)
    axes[0].set_xlabel('MAT')
    axes[0].set_ylabel('Length of record (day)')
    
    axes[1].scatter(temp_data_p['tmp_dc_syr'], temp_data_p['longest_hr']/24)
    axes[1].set_xlabel('MAT')
    axes[1].set_ylabel('Longest period (day)')
    
    axes[2].scatter(temp_data_p['tmp_dc_syr'], temp_data_p['pct_missing'])
    axes[2].set_xlabel('MAT')
    axes[2].set_ylabel('Percent Missing')
    fig.tight_layout()

# %%
# Plotting temporal variables against temperature. 
month_cols = [f'pct_missing_{m:02d}' for m in range(1, 13)]
month_labels = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']

fig, axes = plt.subplots(3, 12, figsize=(24, 6), sharey=True, sharex=True)
for row, param in enumerate(param_subset):
    temp_data_p = temperature_data[temperature_data['parameter'] == param]
    
    for col, mcol in enumerate(month_cols):
        ax = axes[row, col]
        ax.scatter(temp_data_p['tmp_dc_syr'], temp_data_p[mcol], s=5, alpha=0.5)

        if row == 0:
            ax.set_title(month_labels[col], fontsize=8)
        if col == 0:
            ax.set_ylabel(f"(% missing) for {param}", fontsize=8)
        if row == 2:
            ax.set_xlabel('MAT', fontsize=7)

fig.tight_layout()

# %%
months = {1: 'Jan', 4: 'Apr', 7: 'Jul', 10: 'Oct'}
colors = {'Jan': '#a6cee3', 'Apr': '#1f78b4', 'Jul': '#b2df8a', 'Oct': '#33a02c'}

fig, axes = plt.subplots(2, 3, figsize=(12, 5), gridspec_kw={'height_ratios': [3, 1]}, sharex=True)

for i, param in enumerate(param_subset):
    temp_data_p = monthly_temperature_summary[monthly_temperature_summary['parameter'] == param]
    
    for month_num, label in months.items():
        month_data = temp_data_p[temp_data_p['month'] == month_num]
        
        x = month_data['tmp_dc_syr'].values
        y = month_data['pct_missing'].values
        
        # LOWESS smooth
        smoothed = lowess(y, x, frac=0.6, missing='drop')
        axes[0, i].plot(smoothed[:, 0], smoothed[:, 1], label=label, color=colors[label], linewidth=2)
    
    # Histogram of MAT distribution
    x_all = temp_data_p['tmp_dc_syr'].dropna().values
    axes[1, i].hist(x_all, bins=20, 
                     facecolor=PARAM_COLORS[param]['fill'], 
                     edgecolor=PARAM_COLORS[param]['edge'], 
                     alpha=0.8,
                   density=True)
    axes[1, i].set_xlabel('MAT')
    axes[1, i].set_ylabel('Frac. of station-years' if i == 0 else '')

    # Aesthetic parameters
    axes[0, i].text(19.8, 93, param_pretty[param], horizontalalignment='right')
    if i == 0:
        axes[0, i].set_ylabel('Percent of record missing (no data)')
    axes[0, i].legend(fontsize=7, loc='upper right', bbox_to_anchor=(1, 0.9))

    axes[0, i].set_xlim(5, 20)
    axes[1, i].set_xlim(5, 20)
    axes[0, i].set_ylim(0, 100)
    axes[1, i].set_ylim(0, 0.3)    

fig.tight_layout()
plt.savefig(f'../OUTPUT/temporal_patterns/record_missing_monthly_MAT.png', dpi=600, bbox_inches='tight')
