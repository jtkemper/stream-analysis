# %% [markdown]
# # Analysis of temporal analysis
# This code was written by Sai and Danyka Byrnes

# %%
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from config import *

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# #### Answer the following questions based on the timeseries data:
# 1) Percentage of data missing between the start and end date.
#
# 2) The length between start and end datetime (hour)
#
# 3) longest continous recored between the start and end date.

# %%
# List of possible parameters
parameters = [
    "WTemp_C", "SpC_uScm", "DO_mgL", "pH",
    "Turb_FNU", "Turb_NTU", "NO3_mgNL",
    "fDOM_QSU", "fDOM_RFU", "DOC_mgL",
    "PO4_mgL", "Chla_ugL", "Chla_RFU",
    "PC_ugL", "PC_RFU"
]

PARAM_COLORS = {
    'DO_mgL':    {'fill': '#FEDCBB', 'edge': '#7F2704'},
    'SpC_uScm':  {'fill': '#E2EDF8', 'edge': '#08306B'},
    'Turb_FNU':  {'fill': '#CEECC8', 'edge': '#00431A'},
}

param_pretty = {"WTemp_C":"Temp (°C)",
                "SpC_uScm":"SpC (µS/cm)",
                "DO_mgL":"DO (mg/L)",
                "pH":"pH",
                "Turb_FNU":"Turbidity (FNU)",
                "Turb_NTU":"Turbidity (NTU)",
                "NO3_mgNL":"NO₃-N (mg/L)",
                "fDOM_QSU":"fDOM (QSU)",
                "fDOM_RFU":"fDOM (RFU)",
                "DOC_mgL":"DOC (mg/L)",
                "PO4_mgL":"PO₄ (mg/L)",
                "Chla_ugL":"Chl-a (µg/L)",
                "Chla_RFU":"Chl-a (RFU)",
                "PC_ugL":"PC (µg/L)",
                "PC_RFU":"PC (RFU)",
               }

param_subset = ['SpC_uScm','DO_mgL','Turb_FNU']

# %%
# Store all results
results = []

# Loop through each CSV
for file in os.listdir(water_quality_filepath):
    if not file.endswith(".csv"):
        continue

    file_path = os.path.join(water_quality_filepath, file)
    
    # Extract STREAM_ID from filename (remove .csv)
    stream_id = os.path.splitext(file)[0]

    df = pd.read_csv(file_path, low_memory=False) # mixed data types in df, maybe worth double checking

    if "DateTime" not in df.columns:
        continue

    # Convert DateTime
    df["DateTime"] = pd.to_datetime(df["DateTime"], errors="coerce")
    df = df.dropna(subset=["DateTime"])
    df = df.sort_values("DateTime")

    # Create full hourly range
    start = df["DateTime"].min()
    end = df["DateTime"].max()
    full_range = pd.date_range(start=start, end=end, freq="h")

    # Reindex to full hourly timeline
    df = df.set_index("DateTime").reindex(full_range)

    # Total expected length in hours
    total_hours = len(full_range)

    station_result = {"STREAM_ID": stream_id}

    for param in parameters:
        if param in df.columns:

            series = df[param]

            # 1 Percentage Missing
            missing_count = series.isna().sum()
            percent_missing = (missing_count / total_hours) * 100

            # 2 Length between start and end
            length_hours = total_hours

            # 3 Longest continuous record (non-missing streak)
            not_na = series.notna().astype(int)
            groups = (not_na.diff() != 0).cumsum()
            streak_lengths = not_na.groupby(groups).sum()
            longest_streak = streak_lengths.max() if len(streak_lengths) > 0 else 0

            # 4 Seasonal gaps. 
            monthly_pct = series.groupby(series.index.to_period("M")).apply(
                lambda x: x.isna().mean() * 100
            )
            median_by_month = monthly_pct.groupby(monthly_pct.index.month).median()

            station_result[f"{param}_pct_missing"] = round(percent_missing, 2)
            station_result[f"{param}_length_hr"] = length_hours
            station_result[f"{param}_longest_hr"] = int(longest_streak)

            for month_num in range(1, 13):
                col = f"{param}_pct_missing_{month_num:02d}"
                if month_num in median_by_month.index:
                    station_result[col] = round(median_by_month[month_num], 2)
                else:
                    station_result[col] = np.nan

        else:
            station_result[f"{param}_pct_missing"] = np.nan
            station_result[f"{param}_length_hr"] = np.nan
            station_result[f"{param}_longest_hr"] = np.nan
            for month_num in range(1, 13):
                station_result[f"{param}_pct_missing_{month_num:02d}"] = np.nan
            
    results.append(station_result)

# Convert to dataframe
temporal_summary = pd.DataFrame(results)
temporal_summary.head()
# Out:
#            STREAM_ID  WTemp_C_pct_missing  WTemp_C_length_hr  \
# 0  STREAM-gauge-1012                40.93             8995.0
# 1  STREAM-gauge-1013                47.47             8637.0
# 2  STREAM-gauge-1014                 0.00             1456.0
# 3  STREAM-gauge-1042                 0.48             4561.0
# 4  STREAM-gauge-1043                50.22            35471.0
#
#    WTemp_C_longest_hr  WTemp_C_pct_missing_01  WTemp_C_pct_missing_02  \
# 0              2367.0                   100.0                   100.0
# 1              2355.0                   100.0                   100.0
# 2              1456.0                     NaN                     NaN
# 3              2625.0                     NaN                     NaN
# 4              3960.0                   100.0                   100.0
#
#    WTemp_C_pct_missing_03  WTemp_C_pct_missing_04  WTemp_C_pct_missing_05  \
# 0                   100.0                   75.97                     0.0
# 1                   100.0                   82.92                     3.9
# 2                     NaN                     NaN                     NaN
# 3                     NaN                     NaN                     0.0
# 4                   100.0                   47.50                     0.0
#
#    WTemp_C_pct_missing_06  WTemp_C_pct_missing_07  WTemp_C_pct_missing_08  \
# 0                    0.14                    0.00                    0.22
# 1                    2.08                   36.69                   13.64
# 2                    0.00                    0.00                    0.00
# 3                    0.00                    2.02                    0.00
# 4                    0.00                    0.00                    0.00
#
#    WTemp_C_pct_missing_09  WTemp_C_pct_missing_10  WTemp_C_pct_missing_11  \
# 0                    0.00                    0.00                   31.81
# 1                    0.00                    0.00                   30.42
# 2                     NaN                     NaN                     NaN
# 3                    0.00                    0.00                    1.33
# 4                    0.07                   54.03                  100.00
#
#    WTemp_C_pct_missing_12  SpC_uScm_pct_missing  SpC_uScm_length_hr  \
# 0                   100.0                   NaN                 NaN
# 1                   100.0                   NaN                 NaN
# 2                     NaN                   NaN                 NaN
# 3                     NaN                  0.92              4561.0
# 4                   100.0                 50.15             35471.0
#
#    SpC_uScm_longest_hr  SpC_uScm_pct_missing_01  SpC_uScm_pct_missing_02  \
# 0                  NaN                      NaN                      NaN
# 1                  NaN                      NaN                      NaN
# 2                  NaN                      NaN                      NaN
# 3               2766.0                      NaN                      NaN
# 4               4368.0                    100.0                    100.0
#
#    SpC_uScm_pct_missing_03  SpC_uScm_pct_missing_04  SpC_uScm_pct_missing_05  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      0.0
# 4                    100.0                     47.5                      0.0
#
#    SpC_uScm_pct_missing_06  SpC_uScm_pct_missing_07  SpC_uScm_pct_missing_08  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                     0.14                     2.02                     0.00
# 4                     0.00                     0.00                     0.07
#
#    SpC_uScm_pct_missing_09  SpC_uScm_pct_missing_10  SpC_uScm_pct_missing_11  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                     0.00                     0.00                     4.93
# 4                     0.07                    54.03                   100.00
#
#    SpC_uScm_pct_missing_12  DO_mgL_pct_missing  DO_mgL_length_hr  \
# 0                      NaN               41.29            8995.0
# 1                      NaN               47.44            8637.0
# 2                      NaN                 NaN               NaN
# 3                      NaN               27.52            4561.0
# 4                    100.0               63.68           35471.0
#
#    DO_mgL_longest_hr  DO_mgL_pct_missing_01  DO_mgL_pct_missing_02  \
# 0             1098.0                  100.0                  100.0
# 1             2355.0                  100.0                  100.0
# 2                NaN                    NaN                    NaN
# 3             1555.0                    NaN                    NaN
# 4             2988.0                  100.0                  100.0
#
#    DO_mgL_pct_missing_03  DO_mgL_pct_missing_04  DO_mgL_pct_missing_05  \
# 0                  100.0                  75.97                   3.49
# 1                  100.0                  82.50                   3.90
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                   0.00
# 4                  100.0                  58.82                  43.95
#
#    DO_mgL_pct_missing_06  DO_mgL_pct_missing_07  DO_mgL_pct_missing_08  \
# 0                   0.14                  12.50                   0.00
# 1                   1.94                  36.69                  13.85
# 2                    NaN                    NaN                    NaN
# 3                  80.69                  80.24                   0.00
# 4                  35.00                  17.74                  17.34
#
#    DO_mgL_pct_missing_09  DO_mgL_pct_missing_10  DO_mgL_pct_missing_11  \
# 0                   0.14                   1.48                  30.97
# 1                   0.00                   0.00                  30.42
# 2                    NaN                    NaN                    NaN
# 3                   7.78                   2.69                   0.19
# 4                  37.08                  70.83                 100.00
#
#    DO_mgL_pct_missing_12  pH_pct_missing  pH_length_hr  pH_longest_hr  \
# 0                  100.0           40.87        8995.0         2708.0
# 1                  100.0           48.03        8637.0         2355.0
# 2                    NaN             NaN           NaN            NaN
# 3                    NaN            6.29        4561.0         2154.0
# 4                  100.0             NaN           NaN            NaN
#
#    pH_pct_missing_01  pH_pct_missing_02  pH_pct_missing_03  pH_pct_missing_04  \
# 0              100.0              100.0              100.0              75.97
# 1              100.0              100.0              100.0              88.19
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
#
#    pH_pct_missing_05  pH_pct_missing_06  pH_pct_missing_07  pH_pct_missing_08  \
# 0               0.00               0.14              12.50               0.00
# 1               5.11               2.08              36.69              13.85
# 2                NaN                NaN                NaN                NaN
# 3               0.00               0.28              38.17               0.00
# 4                NaN                NaN                NaN                NaN
#
#    pH_pct_missing_09  pH_pct_missing_10  pH_pct_missing_11  pH_pct_missing_12  \
# 0                0.0               0.00              30.97              100.0
# 1                0.0               0.00              30.42              100.0
# 2                NaN                NaN                NaN                NaN
# 3                0.0               0.13               0.00                NaN
# 4                NaN                NaN                NaN                NaN
#
#    Turb_FNU_pct_missing  Turb_FNU_length_hr  Turb_FNU_longest_hr  \
# 0                 51.43              8995.0               1906.0
# 1                 49.08              8637.0               2254.0
# 2                   NaN                 NaN                  NaN
# 3                 28.02              4561.0                590.0
# 4                 63.48             35471.0                960.0
#
#    Turb_FNU_pct_missing_01  Turb_FNU_pct_missing_02  Turb_FNU_pct_missing_03  \
# 0                    100.0                    100.0                    100.0
# 1                    100.0                    100.0                    100.0
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                    100.0                    100.0                    100.0
#
#    Turb_FNU_pct_missing_04  Turb_FNU_pct_missing_05  Turb_FNU_pct_missing_06  \
# 0                    75.97                     5.78                    14.58
# 1                    82.50                    21.51                     2.08
# 2                      NaN                      NaN                      NaN
# 3                      NaN                   100.00                    32.36
# 4                    47.50                    27.82                    14.65
#
#    Turb_FNU_pct_missing_07  Turb_FNU_pct_missing_08  Turb_FNU_pct_missing_09  \
# 0                    12.57                     0.00                     0.00
# 1                    36.69                    13.85                     0.00
# 2                      NaN                      NaN                      NaN
# 3                    23.12                    34.68                     6.67
# 4                    33.87                    40.52                    27.50
#
#    Turb_FNU_pct_missing_10  Turb_FNU_pct_missing_11  Turb_FNU_pct_missing_12  \
# 0                    40.99                   100.00                    100.0
# 1                     0.00                    31.81                    100.0
# 2                      NaN                      NaN                      NaN
# 3                    25.40                     3.04                      NaN
# 4                    74.08                   100.00                    100.0
#
#    Turb_NTU_pct_missing  Turb_NTU_length_hr  Turb_NTU_longest_hr  \
# 0                   NaN                 NaN                  NaN
# 1                   NaN                 NaN                  NaN
# 2                   NaN                 NaN                  NaN
# 3                   NaN                 NaN                  NaN
# 4                   NaN                 NaN                  NaN
#
#    Turb_NTU_pct_missing_01  Turb_NTU_pct_missing_02  Turb_NTU_pct_missing_03  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    Turb_NTU_pct_missing_04  Turb_NTU_pct_missing_05  Turb_NTU_pct_missing_06  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    Turb_NTU_pct_missing_07  Turb_NTU_pct_missing_08  Turb_NTU_pct_missing_09  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    Turb_NTU_pct_missing_10  Turb_NTU_pct_missing_11  Turb_NTU_pct_missing_12  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    NO3_mgNL_pct_missing  NO3_mgNL_length_hr  NO3_mgNL_longest_hr  \
# 0                   NaN                 NaN                  NaN
# 1                   NaN                 NaN                  NaN
# 2                   NaN                 NaN                  NaN
# 3                   NaN                 NaN                  NaN
# 4                   NaN                 NaN                  NaN
#
#    NO3_mgNL_pct_missing_01  NO3_mgNL_pct_missing_02  NO3_mgNL_pct_missing_03  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    NO3_mgNL_pct_missing_04  NO3_mgNL_pct_missing_05  NO3_mgNL_pct_missing_06  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    NO3_mgNL_pct_missing_07  NO3_mgNL_pct_missing_08  NO3_mgNL_pct_missing_09  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    NO3_mgNL_pct_missing_10  NO3_mgNL_pct_missing_11  NO3_mgNL_pct_missing_12  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    fDOM_QSU_pct_missing  fDOM_QSU_length_hr  fDOM_QSU_longest_hr  \
# 0                   NaN                 NaN                  NaN
# 1                   NaN                 NaN                  NaN
# 2                   NaN                 NaN                  NaN
# 3                   NaN                 NaN                  NaN
# 4                   NaN                 NaN                  NaN
#
#    fDOM_QSU_pct_missing_01  fDOM_QSU_pct_missing_02  fDOM_QSU_pct_missing_03  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    fDOM_QSU_pct_missing_04  fDOM_QSU_pct_missing_05  fDOM_QSU_pct_missing_06  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    fDOM_QSU_pct_missing_07  fDOM_QSU_pct_missing_08  fDOM_QSU_pct_missing_09  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    fDOM_QSU_pct_missing_10  fDOM_QSU_pct_missing_11  fDOM_QSU_pct_missing_12  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    fDOM_RFU_pct_missing  fDOM_RFU_length_hr  fDOM_RFU_longest_hr  \
# 0                   NaN                 NaN                  NaN
# 1                   NaN                 NaN                  NaN
# 2                   NaN                 NaN                  NaN
# 3                   NaN                 NaN                  NaN
# 4                   NaN                 NaN                  NaN
#
#    fDOM_RFU_pct_missing_01  fDOM_RFU_pct_missing_02  fDOM_RFU_pct_missing_03  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    fDOM_RFU_pct_missing_04  fDOM_RFU_pct_missing_05  fDOM_RFU_pct_missing_06  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    fDOM_RFU_pct_missing_07  fDOM_RFU_pct_missing_08  fDOM_RFU_pct_missing_09  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    fDOM_RFU_pct_missing_10  fDOM_RFU_pct_missing_11  fDOM_RFU_pct_missing_12  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    DOC_mgL_pct_missing  DOC_mgL_length_hr  DOC_mgL_longest_hr  \
# 0                  NaN                NaN                 NaN
# 1                  NaN                NaN                 NaN
# 2                  NaN                NaN                 NaN
# 3                  NaN                NaN                 NaN
# 4                  NaN                NaN                 NaN
#
#    DOC_mgL_pct_missing_01  DOC_mgL_pct_missing_02  DOC_mgL_pct_missing_03  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
# 2                     NaN                     NaN                     NaN
# 3                     NaN                     NaN                     NaN
# 4                     NaN                     NaN                     NaN
#
#    DOC_mgL_pct_missing_04  DOC_mgL_pct_missing_05  DOC_mgL_pct_missing_06  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
# 2                     NaN                     NaN                     NaN
# 3                     NaN                     NaN                     NaN
# 4                     NaN                     NaN                     NaN
#
#    DOC_mgL_pct_missing_07  DOC_mgL_pct_missing_08  DOC_mgL_pct_missing_09  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
# 2                     NaN                     NaN                     NaN
# 3                     NaN                     NaN                     NaN
# 4                     NaN                     NaN                     NaN
#
#    DOC_mgL_pct_missing_10  DOC_mgL_pct_missing_11  DOC_mgL_pct_missing_12  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
# 2                     NaN                     NaN                     NaN
# 3                     NaN                     NaN                     NaN
# 4                     NaN                     NaN                     NaN
#
#    PO4_mgL_pct_missing  PO4_mgL_length_hr  PO4_mgL_longest_hr  \
# 0                  NaN                NaN                 NaN
# 1                  NaN                NaN                 NaN
# 2                  NaN                NaN                 NaN
# 3                  NaN                NaN                 NaN
# 4                  NaN                NaN                 NaN
#
#    PO4_mgL_pct_missing_01  PO4_mgL_pct_missing_02  PO4_mgL_pct_missing_03  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
# 2                     NaN                     NaN                     NaN
# 3                     NaN                     NaN                     NaN
# 4                     NaN                     NaN                     NaN
#
#    PO4_mgL_pct_missing_04  PO4_mgL_pct_missing_05  PO4_mgL_pct_missing_06  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
# 2                     NaN                     NaN                     NaN
# 3                     NaN                     NaN                     NaN
# 4                     NaN                     NaN                     NaN
#
#    PO4_mgL_pct_missing_07  PO4_mgL_pct_missing_08  PO4_mgL_pct_missing_09  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
# 2                     NaN                     NaN                     NaN
# 3                     NaN                     NaN                     NaN
# 4                     NaN                     NaN                     NaN
#
#    PO4_mgL_pct_missing_10  PO4_mgL_pct_missing_11  PO4_mgL_pct_missing_12  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
# 2                     NaN                     NaN                     NaN
# 3                     NaN                     NaN                     NaN
# 4                     NaN                     NaN                     NaN
#
#    Chla_ugL_pct_missing  Chla_ugL_length_hr  Chla_ugL_longest_hr  \
# 0                   NaN                 NaN                  NaN
# 1                   NaN                 NaN                  NaN
# 2                   NaN                 NaN                  NaN
# 3                   NaN                 NaN                  NaN
# 4                   NaN                 NaN                  NaN
#
#    Chla_ugL_pct_missing_01  Chla_ugL_pct_missing_02  Chla_ugL_pct_missing_03  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    Chla_ugL_pct_missing_04  Chla_ugL_pct_missing_05  Chla_ugL_pct_missing_06  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    Chla_ugL_pct_missing_07  Chla_ugL_pct_missing_08  Chla_ugL_pct_missing_09  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    Chla_ugL_pct_missing_10  Chla_ugL_pct_missing_11  Chla_ugL_pct_missing_12  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    Chla_RFU_pct_missing  Chla_RFU_length_hr  Chla_RFU_longest_hr  \
# 0                   NaN                 NaN                  NaN
# 1                   NaN                 NaN                  NaN
# 2                   NaN                 NaN                  NaN
# 3                   NaN                 NaN                  NaN
# 4                   NaN                 NaN                  NaN
#
#    Chla_RFU_pct_missing_01  Chla_RFU_pct_missing_02  Chla_RFU_pct_missing_03  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    Chla_RFU_pct_missing_04  Chla_RFU_pct_missing_05  Chla_RFU_pct_missing_06  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    Chla_RFU_pct_missing_07  Chla_RFU_pct_missing_08  Chla_RFU_pct_missing_09  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    Chla_RFU_pct_missing_10  Chla_RFU_pct_missing_11  Chla_RFU_pct_missing_12  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    PC_ugL_pct_missing  PC_ugL_length_hr  PC_ugL_longest_hr  \
# 0                 NaN               NaN                NaN
# 1                 NaN               NaN                NaN
# 2                 NaN               NaN                NaN
# 3                 NaN               NaN                NaN
# 4                 NaN               NaN                NaN
#
#    PC_ugL_pct_missing_01  PC_ugL_pct_missing_02  PC_ugL_pct_missing_03  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#    PC_ugL_pct_missing_04  PC_ugL_pct_missing_05  PC_ugL_pct_missing_06  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#    PC_ugL_pct_missing_07  PC_ugL_pct_missing_08  PC_ugL_pct_missing_09  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#    PC_ugL_pct_missing_10  PC_ugL_pct_missing_11  PC_ugL_pct_missing_12  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#    PC_RFU_pct_missing  PC_RFU_length_hr  PC_RFU_longest_hr  \
# 0                 NaN               NaN                NaN
# 1                 NaN               NaN                NaN
# 2                 NaN               NaN                NaN
# 3                 NaN               NaN                NaN
# 4                 NaN               NaN                NaN
#
#    PC_RFU_pct_missing_01  PC_RFU_pct_missing_02  PC_RFU_pct_missing_03  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#    PC_RFU_pct_missing_04  PC_RFU_pct_missing_05  PC_RFU_pct_missing_06  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#    PC_RFU_pct_missing_07  PC_RFU_pct_missing_08  PC_RFU_pct_missing_09  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#    PC_RFU_pct_missing_10  PC_RFU_pct_missing_11  PC_RFU_pct_missing_12
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN

# %%
# Merging the temporal data derived by Sai
# Identify ID/metadata columns (keep these as-is)
id_cols = ['STREAM_ID']

# Reshape
rows = []
for temp_param in parameters:
    temp = temporal_summary[id_cols].copy()
    temp['parameter'] = temp_param
    temp['pct_missing'] = temporal_summary[f'{temp_param}_pct_missing']
    temp['length_hr'] = temporal_summary[f'{temp_param}_length_hr']
    temp['longest_hr'] = temporal_summary[f'{temp_param}_longest_hr']

    # This parameter is the median percentage of the months across the record period that is missing data data. 
    # If the value is 100, it means that in at least one year, that month was in the timeseries, but it missing data
    # If the value is NaN, then the month never appeared in the timeseries.
    for month_num in range(1, 13):
        temp[f'pct_missing_{month_num:02d}'] = temporal_summary[f'{temp_param}_pct_missing_{month_num:02d}']
    rows.append(temp)

temporal_summary_long = (
    pd.concat(rows, ignore_index=True)
    .query('parameter in @parameters')
    .dropna(how='all', subset=['pct_missing', 'length_hr', 'longest_hr'])
)

#temporal_summary_long.to_csv(OUTPUT_filepath+'temporal_statistics.csv', index=False)

# %%
# For now, just set 100 and NaNs both to NaN because I feel like these are corner cases. 
month_cols = [f'pct_missing_{m:02d}' for m in range(1, 13)]
temporal_summary_long[month_cols] = temporal_summary_long[month_cols].replace(np.nan, 100)

temporal_summary_long.head()
# Out:
#            STREAM_ID parameter  pct_missing  length_hr  longest_hr  \
# 0  STREAM-gauge-1012   WTemp_C        40.93     8995.0      2367.0
# 1  STREAM-gauge-1013   WTemp_C        47.47     8637.0      2355.0
# 2  STREAM-gauge-1014   WTemp_C         0.00     1456.0      1456.0
# 3  STREAM-gauge-1042   WTemp_C         0.48     4561.0      2625.0
# 4  STREAM-gauge-1043   WTemp_C        50.22    35471.0      3960.0
#
#    pct_missing_01  pct_missing_02  pct_missing_03  pct_missing_04  \
# 0           100.0           100.0           100.0           75.97
# 1           100.0           100.0           100.0           82.92
# 2           100.0           100.0           100.0          100.00
# 3           100.0           100.0           100.0          100.00
# 4           100.0           100.0           100.0           47.50
#
#    pct_missing_05  pct_missing_06  pct_missing_07  pct_missing_08  \
# 0             0.0            0.14            0.00            0.22
# 1             3.9            2.08           36.69           13.64
# 2           100.0            0.00            0.00            0.00
# 3             0.0            0.00            2.02            0.00
# 4             0.0            0.00            0.00            0.00
#
#    pct_missing_09  pct_missing_10  pct_missing_11  pct_missing_12
# 0            0.00            0.00           31.81           100.0
# 1            0.00            0.00           30.42           100.0
# 2          100.00          100.00          100.00           100.0
# 3            0.00            0.00            1.33           100.0
# 4            0.07           54.03          100.00           100.0

# %%
# Processing metadata, isolating specific parameters
md_wide = pd.read_csv(metadata_filepath+"metadata.csv", dtype = {'sourceID': str})
print(f"Full dataset size: {md_wide.shape[0]}")

for param in param_subset:
    md_wide[param] = md_wide['WQ_parameters'].str.contains(param)

# Removing the stations without data
md_wide = md_wide[(md_wide['SpC_uScm']) | (md_wide['DO_mgL']) | (md_wide['Turb_FNU'])]
print(f"Filtered dataset size: {md_wide.shape[0]}")
# Out:
# Full dataset size: 870
# Filtered dataset size: 556

# %%
md_wide.head()
# Out:
#            STREAM_ID sourceID source                              site name  \
# 0   STREAM-gauge-309  7374525   USGS  Mississippi River at Belle Chasse, LA
# 1   STREAM-gauge-308  7374000   USGS   Mississippi River at Baton Rouge, LA
# 3  STREAM-gauge-2530  7032000   USGS       MISSISSIPPI RIVER AT MEMPHIS, TN
# 5  STREAM-gauge-2203  6934500   USGS          Missouri River at Hermann, MO
# 8  STREAM-gauge-2191  6894650   USGS         Missouri River at Napoleon, MO
#
#    latitude_wgs84  longitude_wgs84  drainagearea_sqkm state_name time_zone  \
# 0       29.857151       -89.977847        2926688.700  Louisiana   Central
# 1       30.445667       -91.191556        2915836.642  Louisiana   Central
# 3       35.123146       -90.077592        2415942.672  Tennessee   Central
# 5       38.709806       -91.438500        1353269.775   Missouri   Central
# 8       39.133611       -94.063889        1256404.149   Missouri   Central
#
#                                        WQ_parameters  SpC_uScm  DO_mgL  \
# 0                                           Turb_FNU     False   False
# 1       WTemp_C,SpC_uScm,DO_mgL,pH,Turb_FNU,NO3_mgNL      True    True
# 3                                           Turb_FNU     False   False
# 5  WTemp_C,SpC_uScm,DO_mgL,pH,Turb_FNU,NO3_mgNL,f...      True    True
# 8       WTemp_C,SpC_uScm,DO_mgL,pH,Turb_FNU,NO3_mgNL      True    True
#
#    Turb_FNU
# 0      True
# 1      True
# 3      True
# 5      True
# 8      True

# %% [markdown]
# ## Seasonal Gaps

# %%
# Reading and filtering 
basinatlas = pd.read_csv(basin_atlas_filepath+"static_basinatlas_catchment_characteristics.csv")
basinatlas = basinatlas[['STREAM_ID',
                         'tmp_dc_syr', # mean annual temperature
                        ]]

param_dict = {'tmp_dc_syr':'MAT'}

# Converting to true values
basinatlas['tmp_dc_syr'] = basinatlas['tmp_dc_syr']/10

# merging MAT with temporal variables
temperature_data = pd.merge(temporal_summary_long, basinatlas, on='STREAM_ID')
temperature_data.head()
# Out:
#            STREAM_ID parameter  pct_missing  length_hr  longest_hr  \
# 0  STREAM-gauge-1012   WTemp_C        40.93     8995.0      2367.0
# 1  STREAM-gauge-1013   WTemp_C        47.47     8637.0      2355.0
# 2  STREAM-gauge-1014   WTemp_C         0.00     1456.0      1456.0
# 3  STREAM-gauge-1042   WTemp_C         0.48     4561.0      2625.0
# 4  STREAM-gauge-1043   WTemp_C        50.22    35471.0      3960.0
#
#    pct_missing_01  pct_missing_02  pct_missing_03  pct_missing_04  \
# 0           100.0           100.0           100.0           75.97
# 1           100.0           100.0           100.0           82.92
# 2           100.0           100.0           100.0          100.00
# 3           100.0           100.0           100.0          100.00
# 4           100.0           100.0           100.0           47.50
#
#    pct_missing_05  pct_missing_06  pct_missing_07  pct_missing_08  \
# 0             0.0            0.14            0.00            0.22
# 1             3.9            2.08           36.69           13.64
# 2           100.0            0.00            0.00            0.00
# 3             0.0            0.00            2.02            0.00
# 4             0.0            0.00            0.00            0.00
#
#    pct_missing_09  pct_missing_10  pct_missing_11  pct_missing_12  tmp_dc_syr
# 0            0.00            0.00           31.81           100.0    4.197165
# 1            0.00            0.00           30.42           100.0    6.800000
# 2          100.00          100.00          100.00           100.0   14.073459
# 3            0.00            0.00            1.33           100.0    5.957540
# 4            0.07           54.03          100.00           100.0    7.554231

# %%
month_cols = [f'pct_missing_{m:02d}' for m in range(1, 13)]
month_labels = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']

fig, axes = plt.subplots(1, 3, figsize=(14, 4), sharey=True)

for i, param in enumerate(param_subset):
    temp_data_p = temperature_data[temperature_data['parameter'] == param]
    n_stations = len(temp_data_p)
    
    freq_100 = [(temp_data_p[mcol] == 100).sum() / n_stations * 100 for mcol in month_cols]
    
    axes[i].bar(month_labels, freq_100)
    axes[i].set_title(param)
    axes[i].set_ylabel('% of stations with no data' if i == 0 else '')
    axes[i].tick_params(axis='x', rotation=45)
    axes[i].set_ylim(0, 50)

fig.tight_layout()
fig.show()
# Out:
# C:\Users\dkbyrnes\AppData\Local\Temp\ipykernel_33828\1418073424.py:19: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# Plotting temporal variables against temperature. 
for param in param_subset:
    # First drop the variables we are not looking at.
    temp_data_p = temperature_data[temperature_data['parameter'].isin([param])]
    # Plot the solutes we are
    fig, axes = plt.subplots(1,3, figsize=(10, 3))
    axes[0].scatter(temp_data_p['tmp_dc_syr'], temp_data_p['length_hr']/24)
    axes[0].set_xlabel('MAT')
    axes[0].set_ylabel('Length of record (day)')
    
    axes[1].scatter(temp_data_p['tmp_dc_syr'], temp_data_p['longest_hr']/24)
    axes[1].set_xlabel('MAT')
    axes[1].set_ylabel('Longest period (day)')
    
    axes[2].scatter(temp_data_p['tmp_dc_syr'], temp_data_p['pct_missing'])
    axes[2].set_xlabel('MAT')
    axes[2].set_ylabel('Percent Missing')
    fig.tight_layout()

# %%
# Plotting temporal variables against temperature. 
month_cols = [f'pct_missing_{m:02d}' for m in range(1, 13)]
month_labels = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']

fig, axes = plt.subplots(3, 12, figsize=(24, 6), sharey=True, sharex=True)
for row, param in enumerate(param_subset):
    temp_data_p = temperature_data[temperature_data['parameter'] == param]
    
    for col, mcol in enumerate(month_cols):
        ax = axes[row, col]
        ax.scatter(temp_data_p['tmp_dc_syr'], temp_data_p[mcol], s=5, alpha=0.5)

        if row == 0:
            ax.set_title(month_labels[col], fontsize=8)
        if col == 0:
            ax.set_ylabel(f"(% missing) for {param}", fontsize=8)
        if row == 2:
            ax.set_xlabel('MAT', fontsize=7)

fig.tight_layout()

# %%
from scipy.stats import gaussian_kde
from statsmodels.nonparametric.smoothers_lowess import lowess

# %%
months = {'Jan': 'pct_missing_01', 'Apr': 'pct_missing_04', 'Jul': 'pct_missing_07', 'Oct': 'pct_missing_10'}
colors = {'Jan': '#a6cee3', 'Apr': '#1f78b4', 'Jul': '#b2df8a', 'Oct': '#33a02c'}

fig, axes = plt.subplots(2, 3, figsize=(14, 5), gridspec_kw={'height_ratios': [3, 1]}, sharex=True)

for i, param in enumerate(param_subset):
    temp_data_p = temperature_data[temperature_data['parameter'] == param]
    
    for label, mcol in months.items():
        
        
        x = temp_data_p['tmp_dc_syr'].values
        y = temp_data_p[mcol].values
        
        # LOWESS smooth
        smoothed = lowess(y, x, frac=0.3, missing='drop')
        axes[0, i].plot(smoothed[:, 0], smoothed[:, 1], label=label, color=colors[label], linewidth=2)
    
    # Histogram of MAT distribution
    x_all = temp_data_p['tmp_dc_syr'].dropna().values
    axes[1, i].hist(x_all, bins=20, 
                     facecolor=PARAM_COLORS[param]['fill'], 
                     edgecolor=PARAM_COLORS[param]['edge'], 
                     alpha=0.8)
    axes[1, i].set_xlabel('MAT')
    axes[1, i].set_ylabel('No. of stations' if i == 0 else '')
    
    # Aesthetic figure features
    if i == 0:
        axes[0, i].set_ylabel('% missing')
    axes[0, i].legend(fontsize=7)
    axes[1, i].set_ylim(0, 75)
    axes[0, i].set_ylim(0, 100)
    axes[0,i].text(-2.25, 2.25, param_pretty[param])

fig.tight_layout()
plt.savefig(f'../OUTPUT/temporal_patterns/parameter_temporal_pattern_MAT.png', dpi=600, bbox_inches='tight')
